# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# # Reading The Necessary file with the python in built os

# %%
import os

# %%
New_Path = "C:/Users/admin/Desktop/FEC Data"

# %%
Summary = os.listdir(New_Path)
Summary
# Out:
# ['All candidates.csv',
#  'All candidates.xlsx',
#  'Any transaction from one committee to another.csv',
#  'Candidate master.csv',
#  'Candidate-committee linkages.csv',
#  'Committee master.csv',
#  'Contributions by individuals.csv',
#  'Contributions from committees to candidates  independent expenditures.csv',
#  'DAX Revision.pbix',
#  'employees dataset.pbix',
#  'FinalReport.docx',
#  'House_Senate current campaigns.csv',
#  'Operating expenditures.csv',
#  'PAC summary.csv',
#  'US STATES.xls',
#  'US STATES.xlsx']

# %%
Candidates_Master = pd.read_csv(New_Path+"/"+Summary[3])

Candidates_Master.columns
# Out:
# Index(['CAND_ID', 'CAND_NAME', 'CAND_PTY_AFFILIATION', 'CAND_ELECTION_YR',
#        'CAND_OFFICE_ST', 'CAND_OFFICE', 'CAND_OFFICE_DISTRICT', 'CAND_ICI',
#        'CAND_STATUS', 'CAND_PCC', 'CAND_ST1', 'CAND_ST2', 'CAND_CITY',
#        'CAND_ST', 'CAND_ZIP'],
#       dtype='object')

# %%
Candidates_Master.head()
# Out:
#      CAND_ID                  CAND_NAME CAND_PTY_AFFILIATION  \
# 0  H0AK00097               COX, JOHN R.                  REP
# 1  H0AL02087               ROBY, MARTHA                  REP
# 2  H0AL02095          JOHN, ROBERT E JR                  IND
# 3  H0AL05049  CRAMER, ROBERT E "BUD" JR                  DEM
# 4  H0AL05163                 BROOKS, MO                  REP
#
#    CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI  \
# 0              2014             AK           H                  0.00        C
# 1              2016             AL           H                  2.00        I
# 2              2016             AL           H                  2.00        C
# 3              2008             AL           H                  5.00      NaN
# 4              2016             AL           H                  5.00        I
#
#   CAND_STATUS   CAND_PCC             CAND_ST1 CAND_ST2     CAND_CITY CAND_ST  \
# 0           N  C00525261       P.O. BOX 1092       NaN  ANCHOR POINT      AK
# 1           C  C00462143           PO BOX 195      NaN    MONTGOMERY      AL
# 2           N        NaN  1465 W OVERBROOK RD      NaN     MILLBROOK      AL
# 3           P  C00239038          PO BOX 2621      NaN    HUNTSVILLE      AL
# 4           C  C00464149   7610 FOXFIRE DRIVE      NaN    HUNTSVILLE      AL
#
#    CAND_ZIP
# 0  99556.00
# 1  36101.00
# 2  36054.00
# 3  35804.00
# 4  35802.00

# %% [markdown]
# # Slicing the Important columns

# %%
Candidates_Master = Candidates_Master.iloc[:, [0,1,2,3,12,13]]
Candidates_Master.isnull().sum()
# Out:
# CAND_ID                  0
# CAND_NAME                0
# CAND_PTY_AFFILIATION    16
# CAND_ELECTION_YR         0
# CAND_CITY                5
# CAND_ST                 65
# dtype: int64

# %%
 Com_Master = pd.read_csv(New_Path + "/" + Summary[5])
Com_Master = Com_Master.iloc[:, [0,1,2,5,6, 7, 10]]
Com_Master.drop("CMTE_PTY_AFFILIATION", axis = 1, inplace = True)

# %%
Com_Master
# Out:
#          CMTE_ID                                            CMTE_NM  \
# 0      C00000059                                 HALLMARK CARDS PAC
# 1      C00000422  AMERICAN MEDICAL ASSOCIATION POLITICAL ACTION ...
# 2      C00000489               D R I V E POLITICAL FUND CHAPTER 886
# 3      C00000547  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMITTEE
# 4      C00000638  INDIANA STATE MEDICAL ASSOCIATION POLITICAL AC...
# ...          ...                                                ...
# 17647  C90017245                                  FRANCISCO AGUILAR
# 17648  C90017336                                     LUDWIG, EUGENE
# 17649  C90017542                CENTER FOR POPULAR DEMOCRACY ACTION
# 17650  C99002396                AMERICAN POLITICAL ACTION COMMITTEE
# 17651  C99003428                    THIRD DISTRICT REPUBLICAN PARTY
#
#                           TRES_NM      CMTE_CITY CMTE_ST   CMTE_ZIP
# 0                     ERIN BROWER    KANSAS CITY      MO      64108
# 1                   WALKER, KEVIN     WASHINGTON      DC      20001
# 2                      TOM RITTER  OKLAHOMA CITY      OK      73107
# 3      C. RICHARD BONEBRAKE, M.D.         TOPEKA      KS      66612
# 4                VIDYA KORA, M.D.   INDIANAPOLIS      IN      46202
# ...                           ...            ...     ...        ...
# 17647                         NaN     HARRISBURG      PA      17101
# 17648                         NaN     WASHINGTON      DC      20007
# 17649                         NaN       BROOKLYN      NY      11237
# 17650               VERSNEL, J.H.       BELLEVUE      WA      98009
# 17651              TOM W BRENEMAN     EAU CLAIRE      WI  547020036
#
# [17652 rows x 6 columns]

# %%
Com_Master.drop(["CMTE_ZIP", "TRES_NM"], axis = 1, inplace = True)

# %%
Candidates_Master.head()
# Out:
#      CAND_ID                  CAND_NAME CAND_PTY_AFFILIATION  \
# 0  H0AK00097               COX, JOHN R.                  REP
# 1  H0AL02087               ROBY, MARTHA                  REP
# 2  H0AL02095          JOHN, ROBERT E JR                  IND
# 3  H0AL05049  CRAMER, ROBERT E "BUD" JR                  DEM
# 4  H0AL05163                 BROOKS, MO                  REP
#
#    CAND_ELECTION_YR     CAND_CITY CAND_ST
# 0              2014  ANCHOR POINT      AK
# 1              2016    MONTGOMERY      AL
# 2              2016     MILLBROOK      AL
# 3              2008    HUNTSVILLE      AL
# 4              2016    HUNTSVILLE      AL

# %%
Com_Master.head()
# Out:
#      CMTE_ID                                            CMTE_NM  \
# 0  C00000059                                 HALLMARK CARDS PAC
# 1  C00000422  AMERICAN MEDICAL ASSOCIATION POLITICAL ACTION ...
# 2  C00000489               D R I V E POLITICAL FUND CHAPTER 886
# 3  C00000547  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMITTEE
# 4  C00000638  INDIANA STATE MEDICAL ASSOCIATION POLITICAL AC...
#
#        CMTE_CITY CMTE_ST
# 0    KANSAS CITY      MO
# 1     WASHINGTON      DC
# 2  OKLAHOMA CITY      OK
# 3         TOPEKA      KS
# 4   INDIANAPOLIS      IN

# %%
Com_Master["CMTE_ST"][10222]="Oregon"
Com_Master[Com_Master["CMTE_ST"].isnull()]
Com_Master.head()
# Out:
#      CMTE_ID                                            CMTE_NM  \
# 0  C00000059                                 HALLMARK CARDS PAC
# 1  C00000422  AMERICAN MEDICAL ASSOCIATION POLITICAL ACTION ...
# 2  C00000489               D R I V E POLITICAL FUND CHAPTER 886
# 3  C00000547  KANSAS MEDICAL SOCIETY POLITICAL ACTION COMMITTEE
# 4  C00000638  INDIANA STATE MEDICAL ASSOCIATION POLITICAL AC...
#
#        CMTE_CITY CMTE_ST
# 0    KANSAS CITY      MO
# 1     WASHINGTON      DC
# 2  OKLAHOMA CITY      OK
# 3         TOPEKA      KS
# 4   INDIANAPOLIS      IN

# %%
cols = ["CMTE_ID", "NAME", "CITY", "STATE", "EMPLOYER", "TRANSACTION_DT", "OCCUPATION", "TRANSACTION_AMT"]

# %% [markdown]
# # Reading The massive individual contributions files with Chunk at 1 million line item per chunk

# %%
FileReader = pd.read_csv(New_Path + "/" + Summary[6], usecols = cols, iterator = True, chunksize = 10**6)

# %%
for index, file in enumerate(Summary):
    print(index,file)
# Out:
# 0 All candidates.csv
# 1 All candidates.xlsx
# 2 Any transaction from one committee to another.csv
# 3 Candidate master.csv
# 4 Candidate-committee linkages.csv
# 5 Committee master.csv
# 6 Contributions by individuals.csv
# 7 Contributions from committees to candidates  independent expenditures.csv
# 8 DAX Revision.pbix
# 9 employees dataset.pbix
# 10 FinalReport.docx
# 11 House_Senate current campaigns.csv
# 12 Operating expenditures.csv
# 13 PAC summary.csv
# 14 US STATES.xls
# 15 US STATES.xlsx

# %%
Com_Linkage =  pd.read_csv(New_Path + "/" + Summary[4])
Com_Linkage
# Out:
#         CAND_ID  CAND_ELECTION_YR  FEC_ELECTION_YR    CMTE_ID CMTE_TP  \
# 0     H0AK00097              2014             2016  C00525261       H
# 1     H0AL02087              2016             2016  C00462143       H
# 2     H0AL02087              2016             2016  C00493783       H
# 3     H0AL05049              2008             2016  C00239038       H
# 4     H0AL05163              2016             2016  C00464149       H
# ...         ...               ...              ...        ...     ...
# 6407  S8WI00026              2016             2016  C00578013       S
# 6408  S8WI00026              2016             2016  C00582940       N
# 6409  S8WI00026              2016             2016  C00602771       S
# 6410  S8WI00026              2016             2016  C00279901       Q
# 6411  S8WI00158              2012             2016  C00501361       S
#
#      CMTE_DSGN  LINKAGE_ID
# 0            P      201860
# 1            P      201861
# 2            J      201862
# 3            P      201863
# 4            P      201864
# ...        ...         ...
# 6407         P      209430
# 6408         J      209728
# 6409         J      210518
# 6410         U      205736
# 6411         P      205737
#
# [6412 rows x 7 columns]

# %% [markdown]
# # Combining, Merging and Joining The relevant files

# %%
size = []
for chunk in FileReader:
    chunk = chunk.merge(Com_Linkage, on = "CMTE_ID").merge(Candidates_Master, on = ["CAND_ID", "CAND_ELECTION_YR"])
    chunk = chunk[chunk["CAND_ELECTION_YR"]==2016]
    chunk = chunk.query('CAND_ID==["P80001571","P00003392"]')
    
    
    size.append(chunk)

# %%
len(size)
# Out:
# 21

# %%
size[1]
# Out:
#           CMTE_ID                 NAME            CITY STATE  \
# 261543  C00575795        ROMERO, TOMAS           DORAL    FL
# 261544  C00575795        SCHOCHET, IRA       TARRYTOWN    NY
# 261545  C00575795      HAN, PING-HSUAN        TORRANCE    CA
# 261546  C00575795      PARTON, WILLIAM       BETHLEHEM    PA
# 261547  C00575795        TAYLOR, GLENN       RIDGELAND    MS
# ...           ...                  ...             ...   ...
# 340012  C00580100        HOWARD, BRUCE          SPRING    TX
# 340013  C00580100     LETNER, MICHELLE          MEDINA    OH
# 340014  C00580100          LEWIS, JOHN          GRAHAM    TX
# 340015  C00580100  LINDEFJELD, SHIRLEY         BEDFORD    NY
# 340016  C00580100      MARTIN, WILLIAM  HUNTINGTON BAY    NY
#
#                                      EMPLOYER         OCCUPATION  \
# 261543                WORLD ATLANTIC AIRLINES                CEO
# 261544                   LABATON SUCHAROW LLP           ATTORNEY
# 261545                          SELF-EMPLOYED    WEDDING PLANNER
# 261546                                    NaN            RETIRED
# 261547    COPELAND, COOK, TAYLOR & BUSH, P.A.           ATTORNEY
# ...                                       ...                ...
# 340012                             UPSNAP INC                CEO
# 340013                                RETIRED            RETIRED
# 340014                          SELF-EMPLOYED        REAL ESTATE
# 340015  RENWICK SOTHEBYS INTERNATIONAL REALTY  REAL ESTATE AGENT
# 340016         WM. E. MARTIN & SONS CO., INC.     SPICE IMPORTER
#
#         TRANSACTION_DT  TRANSACTION_AMT    CAND_ID  CAND_ELECTION_YR  \
# 261543      9282015.00             2700  P00003392              2016
# 261544      8172015.00             2200  P00003392              2016
# 261545      9202015.00             2700  P00003392              2016
# 261546      7152015.00             1000  P00003392              2016
# 261547      8312015.00              250  P00003392              2016
# ...                ...              ...        ...               ...
# 340012      6162015.00              500  P80001571              2016
# 340013      6252015.00              225  P80001571              2016
# 340014      6282015.00              250  P80001571              2016
# 340015      6162015.00              250  P80001571              2016
# 340016      6162015.00             2700  P80001571              2016
#
#         FEC_ELECTION_YR CMTE_TP CMTE_DSGN  LINKAGE_ID  \
# 261543             2016       P         P      209297
# 261544             2016       P         P      209297
# 261545             2016       P         P      209297
# 261546             2016       P         P      209297
# 261547             2016       P         P      209297
# ...                 ...     ...       ...         ...
# 340012             2016       P         P      209560
# 340013             2016       P         P      209560
# 340014             2016       P         P      209560
# 340015             2016       P         P      209560
# 340016             2016       P         P      209560
#
#                                               CAND_NAME CAND_PTY_AFFILIATION  \
# 261543  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 261544  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 261545  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 261546  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 261547  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# ...                                                 ...                  ...
# 340012             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 340013             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 340014             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 340015             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 340016             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
#
#        CAND_CITY CAND_ST
# 261543  NEW YORK      NY
# 261544  NEW YORK      NY
# 261545  NEW YORK      NY
# 261546  NEW YORK      NY
# 261547  NEW YORK      NY
# ...          ...     ...
# 340012  NEW YORK      NY
# 340013  NEW YORK      NY
# 340014  NEW YORK      NY
# 340015  NEW YORK      NY
# 340016  NEW YORK      NY
#
# [16881 rows x 18 columns]

# %%
size[15]["CAND_NAME"].unique()
# Out:
# array(['TRUMP, DONALD J. / MICHAEL R. PENCE ',
#        'CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE'], dtype=object)

# %%
len(size)
# Out:
# 21

# %% [markdown]
# # Combining all The Junk Together

# %%
df = pd.DataFrame()

# %%
df = df.append(size)
df
# Out:
#           CMTE_ID                 NAME                 CITY STATE  \
# 76359   C00575795          ELIAS, JOHN           WASHINGTON    DC
# 76360   C00575795        CLARY, CAROLE               DESTIN    FL
# 76361   C00575795         FEW, MELANIE               DALLAS    TX
# 76362   C00575795    SPURLOCK, MICHAEL            NASHVILLE    TN
# 76363   C00575795   SHIFTON, CONSTANCE          CHERRY HILL    NJ
# ...           ...                  ...                  ...   ...
# 129688  C00580100         FINKEL, MARK    GREENWOOD VILLAGE    CO
# 129689  C00580100         FINKEL, MARK    GREENWOOD VILLAGE    CO
# 129690  C00580100  GERINO, DOROTHY MS.           BELLEVILLE    NJ
# 129691  C00580100        HEWELL, JAMES  SAINT SIMONS ISLAND    GA
# 129692  C00580100  CALDWELL, FRANK MR.               JASPER    AL
#
#                           EMPLOYER                 OCCUPATION  TRANSACTION_DT  \
# 76359   U.S. DEPARTMENT OF JUSTICE                   ATTORNEY      6112015.00
# 76360         CPR OF DESTIN,  INC.  VP/DIRECTOR OF OPERATIONS      6152015.00
# 76361             ACE CASH EXPRESS                  MARKETING      4122015.00
# 76362                          NaN               NOT EMPLOYED      6132015.00
# 76363                SELF-EMPLOYED        EDUCATIONAL ADVISOR      6122015.00
# ...                            ...                        ...             ...
# 129688               SELF-EMPLOYED                    MANAGER     10202016.00
# 129689               SELF-EMPLOYED                    MANAGER     10272016.00
# 129690       INFORMATION REQUESTED      INFORMATION REQUESTED     10072016.00
# 129691                     RETIRED                    RETIRED     10032016.00
# 129692                     RETIRED                    RETIRED     10072016.00
#
#         TRANSACTION_AMT    CAND_ID  CAND_ELECTION_YR  FEC_ELECTION_YR CMTE_TP  \
# 76359               100  P00003392              2016             2016       P
# 76360                50  P00003392              2016             2016       P
# 76361                 5  P00003392              2016             2016       P
# 76362                50  P00003392              2016             2016       P
# 76363                50  P00003392              2016             2016       P
# ...                 ...        ...               ...              ...     ...
# 129688              240  P80001571              2016             2016       P
# 129689              240  P80001571              2016             2016       P
# 129690              240  P80001571              2016             2016       P
# 129691              400  P80001571              2016             2016       P
# 129692              240  P80001571              2016             2016       P
#
#        CMTE_DSGN  LINKAGE_ID                                        CAND_NAME  \
# 76359          P      209297  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 76360          P      209297  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 76361          P      209297  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 76362          P      209297  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 76363          P      209297  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...          ...         ...                                              ...
# 129688         P      209560             TRUMP, DONALD J. / MICHAEL R. PENCE
# 129689         P      209560             TRUMP, DONALD J. / MICHAEL R. PENCE
# 129690         P      209560             TRUMP, DONALD J. / MICHAEL R. PENCE
# 129691         P      209560             TRUMP, DONALD J. / MICHAEL R. PENCE
# 129692         P      209560             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#        CAND_PTY_AFFILIATION CAND_CITY CAND_ST
# 76359                   DEM  NEW YORK      NY
# 76360                   DEM  NEW YORK      NY
# 76361                   DEM  NEW YORK      NY
# 76362                   DEM  NEW YORK      NY
# 76363                   DEM  NEW YORK      NY
# ...                     ...       ...     ...
# 129688                  REP  NEW YORK      NY
# 129689                  REP  NEW YORK      NY
# 129690                  REP  NEW YORK      NY
# 129691                  REP  NEW YORK      NY
# 129692                  REP  NEW YORK      NY
#
# [2664738 rows x 18 columns]

# %%
df["CAND_NAME"].value_counts()
# Out:
# CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE    2516367
# TRUMP, DONALD J. / MICHAEL R. PENCE                 148371
# Name: CAND_NAME, dtype: int64

# %%
len(df)
# Out:
# 2664738

# %%
df = df.reset_index()

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df
# Out:
#           index    CMTE_ID                 NAME                 CITY STATE  \
# 0         76359  C00575795          ELIAS, JOHN           WASHINGTON    DC
# 1         76360  C00575795        CLARY, CAROLE               DESTIN    FL
# 2         76361  C00575795         FEW, MELANIE               DALLAS    TX
# 3         76362  C00575795    SPURLOCK, MICHAEL            NASHVILLE    TN
# 4         76363  C00575795   SHIFTON, CONSTANCE          CHERRY HILL    NJ
# ...         ...        ...                  ...                  ...   ...
# 2664733  129688  C00580100         FINKEL, MARK    GREENWOOD VILLAGE    CO
# 2664734  129689  C00580100         FINKEL, MARK    GREENWOOD VILLAGE    CO
# 2664735  129690  C00580100  GERINO, DOROTHY MS.           BELLEVILLE    NJ
# 2664736  129691  C00580100        HEWELL, JAMES  SAINT SIMONS ISLAND    GA
# 2664737  129692  C00580100  CALDWELL, FRANK MR.               JASPER    AL
#
#                            EMPLOYER                 OCCUPATION  \
# 0        U.S. DEPARTMENT OF JUSTICE                   ATTORNEY
# 1              CPR OF DESTIN,  INC.  VP/DIRECTOR OF OPERATIONS
# 2                  ACE CASH EXPRESS                  MARKETING
# 3                               NaN               NOT EMPLOYED
# 4                     SELF-EMPLOYED        EDUCATIONAL ADVISOR
# ...                             ...                        ...
# 2664733               SELF-EMPLOYED                    MANAGER
# 2664734               SELF-EMPLOYED                    MANAGER
# 2664735       INFORMATION REQUESTED      INFORMATION REQUESTED
# 2664736                     RETIRED                    RETIRED
# 2664737                     RETIRED                    RETIRED
#
#          TRANSACTION_DT  TRANSACTION_AMT    CAND_ID  CAND_ELECTION_YR  \
# 0            6112015.00              100  P00003392              2016
# 1            6152015.00               50  P00003392              2016
# 2            4122015.00                5  P00003392              2016
# 3            6132015.00               50  P00003392              2016
# 4            6122015.00               50  P00003392              2016
# ...                 ...              ...        ...               ...
# 2664733     10202016.00              240  P80001571              2016
# 2664734     10272016.00              240  P80001571              2016
# 2664735     10072016.00              240  P80001571              2016
# 2664736     10032016.00              400  P80001571              2016
# 2664737     10072016.00              240  P80001571              2016
#
#          FEC_ELECTION_YR CMTE_TP CMTE_DSGN  LINKAGE_ID  \
# 0                   2016       P         P      209297
# 1                   2016       P         P      209297
# 2                   2016       P         P      209297
# 3                   2016       P         P      209297
# 4                   2016       P         P      209297
# ...                  ...     ...       ...         ...
# 2664733             2016       P         P      209560
# 2664734             2016       P         P      209560
# 2664735             2016       P         P      209560
# 2664736             2016       P         P      209560
# 2664737             2016       P         P      209560
#
#                                                CAND_NAME CAND_PTY_AFFILIATION  \
# 0        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 1        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 2        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 3        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# 4        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE                  DEM
# ...                                                  ...                  ...
# 2664733             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 2664734             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 2664735             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 2664736             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
# 2664737             TRUMP, DONALD J. / MICHAEL R. PENCE                   REP
#
#         CAND_CITY CAND_ST
# 0        NEW YORK      NY
# 1        NEW YORK      NY
# 2        NEW YORK      NY
# 3        NEW YORK      NY
# 4        NEW YORK      NY
# ...           ...     ...
# 2664733  NEW YORK      NY
# 2664734  NEW YORK      NY
# 2664735  NEW YORK      NY
# 2664736  NEW YORK      NY
# 2664737  NEW YORK      NY
#
# [2664738 rows x 19 columns]

# %%
df = df[df["TRANSACTION_AMT"]>0]

# %%
df = df.reindex(columns = ["TRANSACTION_DT", "NAME", "CAND_ID", "CAND_NAME", "EMPLOYER", "OCCUPATION", "TRANSACTION_AMT", "STATE", "CAND_PTY_AFFILIATION", "CITY"])

# %%
df[df["EMPLOYER"].isnull()]
# Out:
#          TRANSACTION_DT                          NAME    CAND_ID  \
# 3            6132015.00             SPURLOCK, MICHAEL  P00003392
# 5            4142015.00                HARRIS, NICOLE  P00003392
# 6            6152015.00                 GOTTLOB, LYNN  P00003392
# 8            4142015.00                 VENEGAS, JOHN  P00003392
# 25           4132015.00              RITCHIN, BARBARA  P00003392
# ...                 ...                           ...        ...
# 2662952     11082016.00               NANA, KAUSHIK J  P80001571
# 2662967     10212016.00                      PLATH, G  P80001571
# 2663886     10052016.00             GIALLO METALS LLC  P80001571
# 2664200     11072016.00              RAFFERTY, GERALD  P80001571
# 2664583     10042016.00  BARGOLD STORAGE SYSTEMS, LLC  P80001571
#
#                                                CAND_NAME EMPLOYER  \
# 3        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 5        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 6        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 8        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 25       CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# ...                                                  ...      ...
# 2662952             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2662967             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2663886             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2664200             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2664583             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
#
#                        OCCUPATION  TRANSACTION_AMT STATE CAND_PTY_AFFILIATION  \
# 3                    NOT EMPLOYED               50    TN                  DEM
# 5                       HOMEMAKER              100    NY                  DEM
# 6                         RETIRED              100    OH                  DEM
# 8                         RETIRED               25    CA                  DEM
# 25                        RETIRED              100    NY                  DEM
# ...                           ...              ...   ...                  ...
# 2662952                       NaN             2700    FL                  REP
# 2662967                       NaN              500    IL                  REP
# 2663886                       NaN              240    NJ                  REP
# 2664200  COMMODITY FUTURES TRADER              400    FL                  REP
# 2664583                       NaN              800    NY                  REP
#
#                      CITY
# 3               NASHVILLE
# 5                NEW YORK
# 6               BEACHWOOD
# 8              CHATSWORTH
# 25               NEW YORK
# ...                   ...
# 2662952           ORLANDO
# 2662967        SCHAUMBURG
# 2663886        COLTS NECK
# 2664200           JUPITER
# 2664583  LONG ISLAND CITY
#
# [768490 rows x 10 columns]

# %%
df[df["OCCUPATION"].isnull()]
# Out:
#          TRANSACTION_DT                          NAME    CAND_ID  \
# 1101         6252015.00                  EVANS, SUSAN  P00003392
# 3126         4262015.00                NEIDICH, ALIZA  P00003392
# 11028        4172015.00          WHEELER MAIER, SALLY  P00003392
# 11038        6192015.00              FOSTER, SARAJANE  P00003392
# 11043        5012015.00                ROMERO, CELINA  P00003392
# ...                 ...                           ...        ...
# 2663886     10052016.00             GIALLO METALS LLC  P80001571
# 2664191     10042016.00                  HOOVER, CARL  P80001571
# 2664241     10032016.00                 SEITZ, THOMAS  P80001571
# 2664362     10122016.00         HOWELL, ROSEMARIE MS.  P80001571
# 2664583     10042016.00  BARGOLD STORAGE SYSTEMS, LLC  P80001571
#
#                                                CAND_NAME       EMPLOYER  \
# 1101     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  SELF-EMPLOYED
# 3126     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE            NaN
# 11028    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  SELF-EMPLOYED
# 11038    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE            NaN
# 11043    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE            NaN
# ...                                                  ...            ...
# 2663886             TRUMP, DONALD J. / MICHAEL R. PENCE             NaN
# 2664191             TRUMP, DONALD J. / MICHAEL R. PENCE   SELF-EMPLOYED
# 2664241             TRUMP, DONALD J. / MICHAEL R. PENCE   SELF-EMPLOYED
# 2664362             TRUMP, DONALD J. / MICHAEL R. PENCE   SELF-EMPLOYED
# 2664583             TRUMP, DONALD J. / MICHAEL R. PENCE             NaN
#
#         OCCUPATION  TRANSACTION_AMT STATE CAND_PTY_AFFILIATION  \
# 1101           NaN               10    CT                  DEM
# 3126           NaN             2700    CA                  DEM
# 11028          NaN             2700    NY                  DEM
# 11038          NaN              750    DC                  DEM
# 11043          NaN              500    TX                  DEM
# ...            ...              ...   ...                  ...
# 2663886        NaN              240    NJ                  REP
# 2664191        NaN              400    MS                  REP
# 2664241        NaN              800    KY                  REP
# 2664362        NaN              400    FL                  REP
# 2664583        NaN              800    NY                  REP
#
#                      CITY
# 1101            GREENWICH
# 3126          LOS ANGELES
# 11028            NEW YORK
# 11038          WASHINGTON
# 11043              AUSTIN
# ...                   ...
# 2663886        COLTS NECK
# 2664191      OLIVE BRANCH
# 2664241       VILLA HILLS
# 2664362        BOCA RATON
# 2664583  LONG ISLAND CITY
#
# [57669 rows x 10 columns]

# %%
df["OCC"] = np.where(df["EMPLOYER"]=="SELF-EMPLOYED", df["OCCUPATION"].fillna("SELF-EMPLOYED"), df["OCCUPATION"])

# %%
df["OCC"] = np.where((df["EMPLOYER"]== np.nan) & (df["OCC"]== np.nan), df["OCC"].fillna("NOT PROVIDED"), df["OCC"])

# %%
df
# Out:
#          TRANSACTION_DT                 NAME    CAND_ID  \
# 0            6112015.00          ELIAS, JOHN  P00003392
# 1            6152015.00        CLARY, CAROLE  P00003392
# 2            4122015.00         FEW, MELANIE  P00003392
# 3            6132015.00    SPURLOCK, MICHAEL  P00003392
# 4            6122015.00   SHIFTON, CONSTANCE  P00003392
# ...                 ...                  ...        ...
# 2664733     10202016.00         FINKEL, MARK  P80001571
# 2664734     10272016.00         FINKEL, MARK  P80001571
# 2664735     10072016.00  GERINO, DOROTHY MS.  P80001571
# 2664736     10032016.00        HEWELL, JAMES  P80001571
# 2664737     10072016.00  CALDWELL, FRANK MR.  P80001571
#
#                                                CAND_NAME  \
# 0        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 3        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 4        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2664733             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664734             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664735             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664736             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664737             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                            EMPLOYER                 OCCUPATION  \
# 0        U.S. DEPARTMENT OF JUSTICE                   ATTORNEY
# 1              CPR OF DESTIN,  INC.  VP/DIRECTOR OF OPERATIONS
# 2                  ACE CASH EXPRESS                  MARKETING
# 3                               NaN               NOT EMPLOYED
# 4                     SELF-EMPLOYED        EDUCATIONAL ADVISOR
# ...                             ...                        ...
# 2664733               SELF-EMPLOYED                    MANAGER
# 2664734               SELF-EMPLOYED                    MANAGER
# 2664735       INFORMATION REQUESTED      INFORMATION REQUESTED
# 2664736                     RETIRED                    RETIRED
# 2664737                     RETIRED                    RETIRED
#
#          TRANSACTION_AMT STATE CAND_PTY_AFFILIATION                 CITY  \
# 0                    100    DC                  DEM           WASHINGTON
# 1                     50    FL                  DEM               DESTIN
# 2                      5    TX                  DEM               DALLAS
# 3                     50    TN                  DEM            NASHVILLE
# 4                     50    NJ                  DEM          CHERRY HILL
# ...                  ...   ...                  ...                  ...
# 2664733              240    CO                  REP    GREENWOOD VILLAGE
# 2664734              240    CO                  REP    GREENWOOD VILLAGE
# 2664735              240    NJ                  REP           BELLEVILLE
# 2664736              400    GA                  REP  SAINT SIMONS ISLAND
# 2664737              240    AL                  REP               JASPER
#
#                                OCC
# 0                         ATTORNEY
# 1        VP/DIRECTOR OF OPERATIONS
# 2                        MARKETING
# 3                     NOT EMPLOYED
# 4              EDUCATIONAL ADVISOR
# ...                            ...
# 2664733                    MANAGER
# 2664734                    MANAGER
# 2664735      INFORMATION REQUESTED
# 2664736                    RETIRED
# 2664737                    RETIRED
#
# [2662041 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# TRANSACTION_DT               0
# NAME                         0
# CAND_ID                      0
# CAND_NAME                    0
# EMPLOYER                768490
# OCCUPATION               57669
# TRANSACTION_AMT              0
# STATE                     5915
# CAND_PTY_AFFILIATION         0
# CITY                       712
# OCC                      53430
# dtype: int64

# %%
df.query('OCC=="SELF-EMPLOYED"')
# Out:
#          TRANSACTION_DT                    NAME    CAND_ID  \
# 1101         6252015.00            EVANS, SUSAN  P00003392
# 11028        4172015.00    WHEELER MAIER, SALLY  P00003392
# 11410        4132015.00  HUNTER HERMANN, TAMARA  P00003392
# 12151        4142015.00          LASRY, ZACHARY  P00003392
# 12386        4202015.00      SULDS, KATHARINE C  P00003392
# ...                 ...                     ...        ...
# 2664241     10032016.00           SEITZ, THOMAS  P80001571
# 2664362     10122016.00   HOWELL, ROSEMARIE MS.  P80001571
# 2664475     10132016.00       LEOPARDI, ANTHONY  P80001571
# 2664498     10122016.00    MOSBACHER, GEORGETTE  P80001571
# 2664642     11072016.00         DIMARCO, GERARD  P80001571
#
#                                                CAND_NAME  \
# 1101     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 11028    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 11410    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 12151    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 12386    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2664241             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664362             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664475             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664498             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664642             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                             EMPLOYER     OCCUPATION  TRANSACTION_AMT STATE  \
# 1101                   SELF-EMPLOYED            NaN               10    CT
# 11028                  SELF-EMPLOYED            NaN             2700    NY
# 11410                  SELF-EMPLOYED            NaN              250    MA
# 12151                  SELF-EMPLOYED            NaN             2700    NY
# 12386                  SELF-EMPLOYED            NaN             2700    NY
# ...                              ...            ...              ...   ...
# 2664241                SELF-EMPLOYED            NaN              800    KY
# 2664362                SELF-EMPLOYED            NaN              400    FL
# 2664475         CORNERSTONE BUILDERS  SELF-EMPLOYED              200    FL
# 2664498                    GME, INC.  SELF-EMPLOYED             2700    NY
# 2664642  GERARD D.DIMARCO LAW OFFICE  SELF-EMPLOYED              400    NY
#
#         CAND_PTY_AFFILIATION           CITY            OCC
# 1101                     DEM      GREENWICH  SELF-EMPLOYED
# 11028                    DEM       NEW YORK  SELF-EMPLOYED
# 11410                    DEM  CHESTNUT HILL  SELF-EMPLOYED
# 12151                    DEM       NEW YORK  SELF-EMPLOYED
# 12386                    DEM       NEW YORK  SELF-EMPLOYED
# ...                      ...            ...            ...
# 2664241                  REP    VILLA HILLS  SELF-EMPLOYED
# 2664362                  REP     BOCA RATON  SELF-EMPLOYED
# 2664475                  REP       FT MYERS  SELF-EMPLOYED
# 2664498                  REP       NEW YORK  SELF-EMPLOYED
# 2664642                  REP      ROCHESTER  SELF-EMPLOYED
#
# [10372 rows x 11 columns]

# %%
df.drop("OCCUPATION", axis = 1, inplace = True)

# %%
df = df.reindex(columns = ["TRANSACTION_DT", "NAME", "CAND_NAME", "EMPLOYER", "OCC", "STATE", "CAND_PTY_AFFILIATION", "CITY", "TRANSACTION_AMT"])

# %%
df[df["OCC"].isnull()]
# Out:
#          TRANSACTION_DT                          NAME  \
# 3126         4262015.00                NEIDICH, ALIZA
# 11038        6192015.00              FOSTER, SARAJANE
# 11043        5012015.00                ROMERO, CELINA
# 11399        6222015.00                STREANO, RALPH
# 11402        5192015.00                   HELD, JULIE
# ...                 ...                           ...
# 2662949     10292016.00              NAKAO, YASUO MR.
# 2662952     11082016.00               NANA, KAUSHIK J
# 2662967     10212016.00                      PLATH, G
# 2663886     10052016.00             GIALLO METALS LLC
# 2664583     10042016.00  BARGOLD STORAGE SYSTEMS, LLC
#
#                                                CAND_NAME EMPLOYER  OCC STATE  \
# 3126     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  NaN    CA
# 11038    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  NaN    DC
# 11043    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  NaN    TX
# 11399    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  NaN    OR
# 11402    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  NaN    OH
# ...                                                  ...      ...  ...   ...
# 2662949             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  NaN    HI
# 2662952             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  NaN    FL
# 2662967             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  NaN    IL
# 2663886             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  NaN    NJ
# 2664583             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  NaN    NY
#
#         CAND_PTY_AFFILIATION              CITY  TRANSACTION_AMT
# 3126                     DEM       LOS ANGELES             2700
# 11038                    DEM        WASHINGTON              750
# 11043                    DEM            AUSTIN              500
# 11399                    DEM          PORTLAND              500
# 11402                    DEM        CINCINNATI             2700
# ...                      ...               ...              ...
# 2662949                  REP        PEARL CITY             2700
# 2662952                  REP           ORLANDO             2700
# 2662967                  REP        SCHAUMBURG              500
# 2663886                  REP        COLTS NECK              240
# 2664583                  REP  LONG ISLAND CITY              800
#
# [53430 rows x 9 columns]

# %%
df["EMPLOYER"] = np.where(df["OCC"]=="NOT EMPLOYED", df["EMPLOYER"].fillna("NOT EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"]=="RETIRED", df["EMPLOYER"].fillna("RETIRED"), df["EMPLOYER"])
df[df["EMPLOYER"].isnull()].query('OCC=="HOMEMAKER"')
# Out:
#          TRANSACTION_DT                     NAME  \
# 5            4142015.00           HARRIS, NICOLE
# 176          6102015.00          CELENZA, PAMELA
# 179          5272015.00         TRULUCK, ANNETTE
# 215          6302015.00           MCLARTY, SALLY
# 217          6232015.00              BAYER, MARY
# ...                 ...                      ...
# 2556923      1112016.00           LITTMAN, DIANE
# 2556976      1072016.00       GRUNWALD, MICHELLE
# 2557002      1182016.00  GRIFFITH, JACQUELINE P.
# 2557054      1182016.00              YORK, SUSAN
# 2557791      7202016.00          POULSON, LAURIE
#
#                                                CAND_NAME EMPLOYER        OCC  \
# 5        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 176      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 179      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 215      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 217      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# ...                                                  ...      ...        ...
# 2556923  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 2556976  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 2557002  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 2557054  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN  HOMEMAKER
# 2557791             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN  HOMEMAKER
#
#         STATE CAND_PTY_AFFILIATION           CITY  TRANSACTION_AMT
# 5          NY                  DEM       NEW YORK              100
# 176        CA                  DEM  BEVERLY HILLS               70
# 179        SC                  DEM     CHARLESTON               25
# 215        AR                  DEM        NEWPORT              100
# 217        CA                  DEM  NEWPORT BEACH               10
# ...       ...                  ...            ...              ...
# 2556923    NY                  DEM       HARRISON             1350
# 2556976    NJ                  DEM       LAKEWOOD             2700
# 2557002    LA                  DEM        HAMMOND             1949
# 2557054    NY                  DEM       NEW YORK             2700
# 2557791    CA                  REP     CHATSWORTH               10
#
# [38736 rows x 9 columns]

# %%
df["EMPLOYER"].value_counts().nlargest(5)
# Out:
# RETIRED          780701
# SELF-EMPLOYED    313641
# NOT EMPLOYED      68421
# NONE               6170
# GOOGLE             4244
# Name: EMPLOYER, dtype: int64

# %%
df["OCC"] = df["OCC"].str.replace("INFORMATION REQUESTED", "NOT PROVIDED")
df["EMPLOYER"] = df["EMPLOYER"].str.replace("INFORMATION REQUESTED", "NOT PROVIDED")
df["EMPLOYER"] = df["EMPLOYER"].str.replace("SELF", "SELF-EMPLOYED")

# %%
df["EMPLOYER"] = np.where(df["OCC"]=="NOT PROVIDED", df["EMPLOYER"].fillna("NOT PROVIDED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("HOMEMAKER"), df["EMPLOYER"].fillna("HOMEMAKER"), df["EMPLOYER"])

# %%
df["OCC"] = np.where(df["EMPLOYER"].str.contains("HOMEMAKER"), df["OCC"].fillna("HOMEMAKER"), df["OCC"])

# %%
df["OCC"] =  np.where(df["EMPLOYER"]=="FACEBOOK", df["OCC"].fillna("SOFTWARE ENGINEER"), df["OCC"])

# %%
df["OCC"] =  np.where(df["EMPLOYER"]=="CPA", df["OCC"].fillna("SELF-EMPLOYED "), df["OCC"])

# %%
df["OCC"] =  np.where(df["EMPLOYER"]=="NOT EMPLOYED", df["OCC"].fillna("NOT EMPLOYED"), df["OCC"])

# %%
df["OCC"] =  np.where(df["EMPLOYER"]=="RETIRED", df["OCC"].fillna("RETIRED"), df["OCC"])

df["EMPLOYER"] =  np.where(df["OCC"]=="RETIRED", df["EMPLOYER"].fillna("RETIRED"), df["EMPLOYER"])

# %%
df["OCC"] =  np.where(df["EMPLOYER"]=="SELF EMPLOYED", df["OCC"].fillna("SELF-EMPLOYED"), df["OCC"])

# %%
df[df["EMPLOYER"]=="ENGINEER"]
# Out:
#          TRANSACTION_DT                   NAME  \
# 1133         5292015.00             LOCK, YING
# 8612         5222015.00             LOCK, YING
# 724258      10012016.00     GAMARRA, FRANCISCO
# 1621202      8312016.00        LOCKLEAR, CHRIS
# 2343787      4242016.00      MAGARRELL, DANIEL
# ...                 ...                    ...
# 2662858     10242016.00         SANDS, KENNETH
# 2662865     10232016.00        BELL, KATHY MR.
# 2662910     10202016.00  GUZ-MONTGOMERY, JAMES
# 2662911     10202016.00  GUZ-MONTGOMERY, JAMES
# 2662944     11062016.00       SHINOHARA, KEITH
#
#                                                CAND_NAME  EMPLOYER  \
# 1133     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  ENGINEER
# 8612     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  ENGINEER
# 724258   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  ENGINEER
# 1621202  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  ENGINEER
# 2343787  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE  ENGINEER
# ...                                                  ...       ...
# 2662858             TRUMP, DONALD J. / MICHAEL R. PENCE   ENGINEER
# 2662865             TRUMP, DONALD J. / MICHAEL R. PENCE   ENGINEER
# 2662910             TRUMP, DONALD J. / MICHAEL R. PENCE   ENGINEER
# 2662911             TRUMP, DONALD J. / MICHAEL R. PENCE   ENGINEER
# 2662944             TRUMP, DONALD J. / MICHAEL R. PENCE   ENGINEER
#
#                                   OCC STATE CAND_PTY_AFFILIATION  \
# 1133                          RETIRED    CA                  DEM
# 8612                          RETIRED    CA                  DEM
# 724258                       ENGINEER    TX                  DEM
# 1621202                      ENGINEER    NC                  DEM
# 2343787                   BAE SYSTEMS    NH                  DEM
# ...                               ...   ...                  ...
# 2662858                         AMCOR    NC                  REP
# 2662865  BELL ENVIRONMENT ENGINEERING    OK                  REP
# 2662910                           NaN    VA                  REP
# 2662911                           NaN    VA                  REP
# 2662944            JONES LANG LASALLE    ZZ                  REP
#
#                   CITY  TRANSACTION_AMT
# 1133     SAN FRANCISCO              100
# 8612     SAN FRANCISCO              150
# 724258         HOUSTON               50
# 1621202       PEMBROKE               25
# 2343787         NASHUA               10
# ...                ...              ...
# 2662858      ASHEVILLE              250
# 2662865        QUITMAN              250
# 2662910     WINCHESTER              250
# 2662911     WINCHESTER              250
# 2662944      HONG KONG             1000
#
# [259 rows x 9 columns]

# %%
df[df["OCC"].isnull()]["EMPLOYER"].value_counts().nlargest(10)
# Out:
# NONE                                    137
# AT&T                                    103
# DISABLED                                 68
# U.S. GOVERNMENT                          58
# ENERGY HEALER                            48
# PURDUE UNIVERSITY                        47
# DIERBERGS                                45
# JANI JED LLC                             45
# SELF-EMPLOYED EMPLOYED                   38
# U.S. DEPARTMENT OF VETERAN'S AFFAIRS     37
# Name: EMPLOYER, dtype: int64

# %%
df[df["OCC"].isnull()]
# Out:
#          TRANSACTION_DT                   NAME  \
# 13570        4252015.00        FIMBRES, LORENA
# 14047        4122015.00           POWER, SUSAN
# 14310        5182015.00       NIYAZOV, DMITRIY
# 14703        6302015.00             FALK, LILY
# 15618        6302015.00      KATZENSTEIN, JOHN
# ...                 ...                    ...
# 2662748     10312016.00            MELL, JAMES
# 2662764     10232016.00    KLINGENSMITH, CATHY
# 2662765     10252016.00    KLINGENSMITH, CATHY
# 2662910     10202016.00  GUZ-MONTGOMERY, JAMES
# 2662911     10202016.00  GUZ-MONTGOMERY, JAMES
#
#                                                CAND_NAME  \
# 13570    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14047    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14310    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14703    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 15618    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2662748             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662764             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662765             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662910             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662911             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                          EMPLOYER  OCC STATE CAND_PTY_AFFILIATION        CITY  \
# 13570                 DIVERSIFIED  NaN    DC                  DEM  WASHINGTON
# 14047              SUSAN V. POWER  NaN    IL                  DEM     CHICAGO
# 14310    FIRST KING INTERNATIONAL  NaN    CA                  DEM     LA MESA
# 14703            LILY OF THE WEST  NaN    NM                  DEM    SANTA FE
# 15618           COGNITIVE CAPITAL  NaN    IL                  DEM     CHICAGO
# ...                           ...  ...   ...                  ...         ...
# 2662748                CONSULTANT  NaN    FL                  REP     REDDICK
# 2662764        PETROLEUM ENGINEER  NaN    TX                  REP     HOUSTON
# 2662765        PETROLEUM ENGINEER  NaN    TX                  REP     HOUSTON
# 2662910                  ENGINEER  NaN    VA                  REP  WINCHESTER
# 2662911                  ENGINEER  NaN    VA                  REP  WINCHESTER
#
#          TRANSACTION_AMT
# 13570               2700
# 14047               2700
# 14310                216
# 14703                250
# 15618               2700
# ...                  ...
# 2662748              250
# 2662764              150
# 2662765              100
# 2662910              250
# 2662911              250
#
# [3816 rows x 9 columns]

# %%
m = df[["EMPLOYER", "OCC"]].isna().all(axis = 1)  # USING MASKING TO FILL MULTIPLE NA IN A DATAFRAME

# %%
df.loc[m, ["EMPLOYER", "OCC"]] = "NOT AVAILABLE"
df[df["OCC"].isna()]
# Out:
#          TRANSACTION_DT                   NAME  \
# 13570        4252015.00        FIMBRES, LORENA
# 14047        4122015.00           POWER, SUSAN
# 14310        5182015.00       NIYAZOV, DMITRIY
# 14703        6302015.00             FALK, LILY
# 15618        6302015.00      KATZENSTEIN, JOHN
# ...                 ...                    ...
# 2662748     10312016.00            MELL, JAMES
# 2662764     10232016.00    KLINGENSMITH, CATHY
# 2662765     10252016.00    KLINGENSMITH, CATHY
# 2662910     10202016.00  GUZ-MONTGOMERY, JAMES
# 2662911     10202016.00  GUZ-MONTGOMERY, JAMES
#
#                                                CAND_NAME  \
# 13570    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14047    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14310    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 14703    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 15618    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2662748             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662764             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662765             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662910             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2662911             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                          EMPLOYER  OCC STATE CAND_PTY_AFFILIATION        CITY  \
# 13570                 DIVERSIFIED  NaN    DC                  DEM  WASHINGTON
# 14047              SUSAN V. POWER  NaN    IL                  DEM     CHICAGO
# 14310    FIRST KING INTERNATIONAL  NaN    CA                  DEM     LA MESA
# 14703            LILY OF THE WEST  NaN    NM                  DEM    SANTA FE
# 15618           COGNITIVE CAPITAL  NaN    IL                  DEM     CHICAGO
# ...                           ...  ...   ...                  ...         ...
# 2662748                CONSULTANT  NaN    FL                  REP     REDDICK
# 2662764        PETROLEUM ENGINEER  NaN    TX                  REP     HOUSTON
# 2662765        PETROLEUM ENGINEER  NaN    TX                  REP     HOUSTON
# 2662910                  ENGINEER  NaN    VA                  REP  WINCHESTER
# 2662911                  ENGINEER  NaN    VA                  REP  WINCHESTER
#
#          TRANSACTION_AMT
# 13570               2700
# 14047               2700
# 14310                216
# 14703                250
# 15618               2700
# ...                  ...
# 2662748              250
# 2662764              150
# 2662765              100
# 2662910              250
# 2662911              250
#
# [3816 rows x 9 columns]

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("RETIRE"), df["EMPLOYER"].str.replace("NONE", "RETIRED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("DISABLE"), df["EMPLOYER"].str.replace("NONE", "DISABLED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("STUDENT"), df["EMPLOYER"].str.replace("NONE","NOT EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("HOME"), df["EMPLOYER"].str.replace("NONE","NOT EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("HOUSEWIFE"), df["EMPLOYER"].str.replace("NONE","NOT EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("DIVORCEE"), df["EMPLOYER"].str.replace("NONE","NOT EMPLOYED"), df["EMPLOYER"])

# %%
df[df["EMPLOYER"]=="NONE"]
# Out:
#          TRANSACTION_DT                     NAME  \
# 6811         6292015.00  MASSA-LOCHRIDGE, LAUREN
# 7039         6162015.00  MASSA-LOCHRIDGE, LAUREN
# 8524         6162015.00  MASSA-LOCHRIDGE, LAUREN
# 8533         4202015.00  MASSA-LOCHRIDGE, LAUREN
# 8944         4132015.00  MASSA-LOCHRIDGE, LAUREN
# ...                 ...                      ...
# 2568676      9142016.00       HOLBROOK, MARY ANN
# 2570330      9132016.00                 MA, CHIN
# 2570358      9062016.00           KELLY, RAYMOND
# 2584040      8022016.00         TWILLEY, BRANDON
# 2592324      8022016.00        CHASSE, ELIZABETH
#
#                                                CAND_NAME EMPLOYER  \
# 6811     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE     NONE
# 7039     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE     NONE
# 8524     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE     NONE
# 8533     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE     NONE
# 8944     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE     NONE
# ...                                                  ...      ...
# 2568676             TRUMP, DONALD J. / MICHAEL R. PENCE      NONE
# 2570330             TRUMP, DONALD J. / MICHAEL R. PENCE      NONE
# 2570358             TRUMP, DONALD J. / MICHAEL R. PENCE      NONE
# 2584040             TRUMP, DONALD J. / MICHAEL R. PENCE      NONE
# 2592324             TRUMP, DONALD J. / MICHAEL R. PENCE      NONE
#
#                                     OCC STATE CAND_PTY_AFFILIATION  \
# 6811     TECHNOLOGY STATEGIST, SNA, CDO    CA                  DEM
# 7039     TECHNOLOGY STATEGIST, SNA, CDO    CA                  DEM
# 8524     TECHNOLOGY STATEGIST, SNA, CDO    CA                  DEM
# 8533     TECHNOLOGY STATEGIST, SNA, CDO    CA                  DEM
# 8944     TECHNOLOGY STATEGIST, SNA, CDO    CA                  DEM
# ...                                 ...   ...                  ...
# 2568676                            NONE    TX                  REP
# 2570330                 IT PROFESSIONAL    NJ                  REP
# 2570358                        SERVICES    IL                  REP
# 2584040                  NONE/LAYER OFF    TX                  REP
# 2592324                REGISTERED NURSE    FL                  REP
#
#                CITY  TRANSACTION_AMT
# 6811       BERKELEY               79
# 7039       BERKELEY               10
# 8524       BERKELEY               30
# 8533       BERKELEY              100
# 8944       BERKELEY               10
# ...             ...              ...
# 2568676    SANTA FE             1000
# 2570330  BEDMINSTER              250
# 2570358     OFALLON              500
# 2584040    LONESTAR              184
# 2592324  FORT MYERS              184
#
# [2228 rows x 9 columns]

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("DISABLED"), df["EMPLOYER"].fillna("DISABLED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("STUDENT"), df["EMPLOYER"].fillna("NOT EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"]=="NOT AVAILABLE", df["EMPLOYER"].fillna("NOT AVAILABLE"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = np.where(df["OCC"].str.contains("RETI"), df["EMPLOYER"].fillna("RETIRED"), df["EMPLOYER"])

# %%
df[df["EMPLOYER"].isnull()]
# Out:
#          TRANSACTION_DT                          NAME  \
# 290          6112015.00                  CANTOR, JANE
# 489          5022015.00                  CANTOR, JANE
# 1869         6142015.00                  CANTOR, JANE
# 4496         4212015.00                  CANTOR, JANE
# 5127         6042015.00                MOODY, BARBARA
# ...                 ...                           ...
# 2661576     11022016.00  BALIDES KEFALIOTIS, VICTORIA
# 2661654     11052016.00                    UNGER, JOE
# 2662941     10302016.00                   SHINA, MARK
# 2662942     10302016.00                   SHINA, MARK
# 2664200     11072016.00              RAFFERTY, GERALD
#
#                                                CAND_NAME EMPLOYER  \
# 290      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 489      CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 1869     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 4496     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# 5127     CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE      NaN
# ...                                                  ...      ...
# 2661576             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2661654             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2662941             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2662942             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
# 2664200             TRUMP, DONALD J. / MICHAEL R. PENCE       NaN
#
#                                      OCC STATE CAND_PTY_AFFILIATION  \
# 290      JUDGE NEW JERSEY SUPERIOR COURT    NY                  DEM
# 489      JUDGE NEW JERSEY SUPERIOR COURT    NY                  DEM
# 1869     JUDGE NEW JERSEY SUPERIOR COURT    NY                  DEM
# 4496     JUDGE NEW JERSEY SUPERIOR COURT    NY                  DEM
# 5127                           VOLUNTEER    AR                  DEM
# ...                                  ...   ...                  ...
# 2661576                           HARRIS    VA                  REP
# 2661654                      POST OFFICE    NY                  REP
# 2662941                             MTEK    NC                  REP
# 2662942                             MTEK    NC                  REP
# 2664200         COMMODITY FUTURES TRADER    FL                  REP
#
#                  CITY  TRANSACTION_AMT
# 290          NEW YORK              100
# 489          NEW YORK              100
# 1869         NEW YORK               75
# 4496         NEW YORK              100
# 5127            SALEM              120
# ...               ...              ...
# 2661576        MCLEAN             2700
# 2661654  POUGHKEEPSIE             1000
# 2662941     OAK RIDGE              250
# 2662942     OAK RIDGE              250
# 2664200       JUPITER              400
#
# [9279 rows x 9 columns]

# %%
occ_mapping = {"INFORMATION REQUESTED": "NOT AVAILABLE"}
df["OCC"] = df["OCC"].map(lambda x: occ_mapping.get(x,x)) # Mapping to change the name

# %%
df.isnull().sum()
# Out:
# TRANSACTION_DT             0
# NAME                       0
# CAND_NAME                  0
# EMPLOYER                9279
# OCC                     3816
# STATE                   5915
# CAND_PTY_AFFILIATION       0
# CITY                     712
# TRANSACTION_AMT            0
# dtype: int64

# %%
df[df["OCC"].isnull()]["EMPLOYER"].value_counts()
# Out:
# RETIRED               137
# AT&T                  103
# DISABLED               68
# U.S. GOVERNMENT        58
# ENERGY HEALER          48
#                      ...
# LMHC FL                 1
# AMERICAN HOSPITAL       1
# BRG HOLDINGS, LLC       1
# PARISH & CASTLEMAN      1
# CAUSECAST               1
# Name: EMPLOYER, Length: 861, dtype: int64

# %%
df["OCC"] = np.where(df["EMPLOYER"]=="AT&T", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"].str.contains("DISABLE"), df["OCC"].fillna("DISABLED"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]=="ENERGY HEALER", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])

# %%
df["EMPLOYER"] = df["EMPLOYER"].str.replace("U.S GOVERNMENT", "U.S. GOVERNMENT" )
# Out:
# C:\Users\admin\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df["OCC"] = np.where(df["EMPLOYER"]=="PURDUE UNIVERSITY", df["OCC"].fillna("PROFESSOR"), df["OCC"])
df["EMPLOYER"] = df["EMPLOYER"].replace("PURDUE", "PURDUE UNIVERSITY")

# %%
df["OCC"] = np.where(df["EMPLOYER"]== "U.S. GOVERNMENT", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "DIERBERGS", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "JANI JED LLC", df["OCC"].fillna("OWNER"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "U.S. DEPARTMENT OF VETERAN'S AFFAIRS", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "LOS ANGELES UNIFIED SCHOOL DISTRICT", df["OCC"].fillna("EDUCATOR"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "VAC", df["OCC"].fillna("CONSTRUCTION MANAGER"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "CLIENT SERVICES, INC.", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "JW MARRIOTT ESTARR PASS", df["OCC"].fillna("EMPLOYEE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "U.S. NAVY", df["OCC"].fillna("NAVAL OFFICER"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "CERINET", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "CITY OF NY, LAW DEPARTMENT", df["OCC"].fillna("LAWYER"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "SEACOAST SCAFFOLD & EQUIPMENT CORPORAT", df["OCC"].fillna("SELF-EMPLOYED"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "U.S. DEPARTMENT OF THE ARMY", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])

# %%
df["OCC"] = np.where(df["EMPLOYER"]== "AIA VIRGINIA", df["OCC"].fillna("ACCOUNTANT"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "WAL-MART", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "ALBANY LAW", df["OCC"].fillna("LAWYER"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "TRULYGREENSOLUTION.COM", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "U.S. TRANSPORTATION SECURITY ADMINISTR", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "SAGE", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "FCC", df["OCC"].fillna("ATTORNEY"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "JC MAXX AUTO REPAIR", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "VCA", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])

# %%
df["OCC"] = np.where(df["EMPLOYER"]== "DUNLAP LILLEY", df["OCC"].fillna("NOT AVAILABLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "CLIENT SERVICES INC.", df["OCC"].fillna("PROGRAMMER ANALYST"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "SHARON KORTE MOLENAAR", df["OCC"].fillna("SINGLE"), df["OCC"])
df["OCC"] = np.where(df["EMPLOYER"]== "CINEMA WELLNESS", df["OCC"].fillna("MANAGER"), df["OCC"])

# %%
df["OCC"] = df["OCC"].fillna("NOT AVILABLE")

# %%
df["EMPLOYER"] = np.where(df["OCC"]=="NOT AVAILABLE", df["EMPLOYER"].fillna("NOT AVAILABLE"), df["EMPLOYER"])
df["EMPLOYER"] = np.where(df["OCC"]=="SELF-EMPLOYED", df["EMPLOYER"].fillna("SELF-EMPLOYED"), df["EMPLOYER"])

# %%
df["EMPLOYER"] = df["EMPLOYER"].fillna("NOT AVAILABLE")

# %%
df["STATE"] = df["STATE"].fillna("FOREIGN")
df["CITY"] = np.where(df["STATE"]=="FOREIGN", df["CITY"].fillna("FOREIGN CITY"), df["CITY"])

# %%
df[df["CITY"].isna()]
# Out:
#          TRANSACTION_DT                     NAME  \
# 23114        5272015.00        POLSKIN, PHILIPPA
# 64493       11132015.00          SCHOLZ, MELISSA
# 74926       12212015.00  SUN, DANNIENA CHING WAN
# 131535      11062016.00         OLIVIER, WREN I.
# 150039      10292016.00           FARRELL, BRIAN
# ...                 ...                      ...
# 2237853      3082016.00  STOUFFER, SPENCER R. II
# 2395033      4052016.00            WILSON, PEGGY
# 2493765      5272016.00            CHIBBA, SUNIL
# 2537063      5282016.00            RAGIMOV, NARA
# 2551010      1182016.00       WILSON, SEVETRI M.
#
#                                                CAND_NAME  \
# 23114    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 64493    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 74926    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 131535   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 150039   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2237853  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2395033  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2493765  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2537063  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2551010  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                        EMPLOYER                   OCC STATE  \
# 23114    ARTS AND COMMUNICATION COUNSELORS, INC             PRESIDENT    AR
# 64493                      SCHOLZ NONPROFIT LAW              ATTORNEY    WI
# 74926                      LJC INVESTMENTS INC.             PRESIDENT    CA
# 131535                   SELF-EMPLOYED-EMPLOYED                FARMER    VA
# 150039                            VIP MENTORING      VOLUNTEER MENTOR    MI
# ...                                         ...                   ...   ...
# 2237853                   TRAMMELL CROW COMPANY     MANAGING DIRECTOR    VA
# 2395033                                 RETIRED               RETIRED    UT
# 2493765                               HOMEMAKER             HOMEMAKER    GA
# 2537063                        BERGDORF GOODMAN  BRIDAL SALON MANAGER    NY
# 2551010                  SELF-EMPLOYED-EMPLOYED            CONSULTANT    LA
#
#         CAND_PTY_AFFILIATION CITY  TRANSACTION_AMT
# 23114                    DEM  NaN             2700
# 64493                    DEM  NaN              300
# 74926                    DEM  NaN             2700
# 131535                   DEM  NaN               25
# 150039                   DEM  NaN              100
# ...                      ...  ...              ...
# 2237853                  DEM  NaN             1000
# 2395033                  DEM  NaN             1000
# 2493765                  DEM  NaN             2700
# 2537063                  DEM  NaN              500
# 2551010                  DEM  NaN             2700
#
# [87 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# TRANSACTION_DT           0
# NAME                     0
# CAND_NAME                0
# EMPLOYER                 0
# OCC                      0
# STATE                    0
# CAND_PTY_AFFILIATION     0
# CITY                    87
# TRANSACTION_AMT          0
# dtype: int64

# %%
df["CAND_NAME"]
# Out:
# 0          CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1          CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2          CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 3          CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 4          CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#                                 ...
# 2664733               TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664734               TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664735               TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664736               TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664737               TRUMP, DONALD J. / MICHAEL R. PENCE
# Name: CAND_NAME, Length: 2662041, dtype: object

# %%
cand_mapping = {"CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE": "HILLARY CLINTON",
                "TRUMP, DONALD J. / MICHAEL R. PENCE": "DONALD TRUMP"}

# %%
import xlrd

# %%
Summary
# Out:
# ['All candidates.csv',
#  'All candidates.xlsx',
#  'Any transaction from one committee to another.csv',
#  'Candidate master.csv',
#  'Candidate-committee linkages.csv',
#  'Committee master.csv',
#  'Contributions by individuals.csv',
#  'Contributions from committees to candidates  independent expenditures.csv',
#  'DAX Revision.pbix',
#  'employees dataset.pbix',
#  'FinalReport.docx',
#  'House_Senate current campaigns.csv',
#  'Operating expenditures.csv',
#  'PAC summary.csv',
#  'US STATES.xls',
#  'US STATES.xlsx']

# %%
State = pd.read_excel(New_Path + "/" + Summary[-1], header = 
                      None, skiprows=2)

# %%
State
# Out:
#      0   1      2               3
# 0  NaN NaN  STATE         CAPITAL
# 1  NaN NaN     AL      MONTGOMERY
# 2  NaN NaN     AK         JUNEAUE
# 3  NaN NaN     AZ         PHOENIX
# 4  NaN NaN     AR     LITTLE ROCK
# 5  NaN NaN     CA      SACRAMENTO
# 6  NaN NaN     CO          DENVER
# 7  NaN NaN     CT        HARTFORD
# 8  NaN NaN     DE           DOVER
# 9  NaN NaN     FL     TALLAHASSEE
# 10 NaN NaN     GA         ATLANTA
# 11 NaN NaN     HI        HONOLOLU
# 12 NaN NaN     ID           BOISE
# 13 NaN NaN     IL     SPRINGFIELD
# 14 NaN NaN     IN    INDIANAPOLIS
# 15 NaN NaN     IA      DES MOINES
# 16 NaN NaN     KS          TOPEKA
# 17 NaN NaN     KY       FRANKFORT
# 18 NaN NaN     LA    BATON TROUGE
# 19 NaN NaN     ME         AUGUSTA
# 20 NaN NaN     MD       ANNAPOLIS
# 21 NaN NaN     MA          BOSTON
# 22 NaN NaN     MI         LANSING
# 23 NaN NaN     MN        ST. PAUL
# 24 NaN NaN     MS         JACKSON
# 25 NaN NaN     MO  JEFFERSON CITY
# 26 NaN NaN     MT          HELENA
# 27 NaN NaN     NE         LINCOLN
# 28 NaN NaN     NV     CARSON CITY
# 29 NaN NaN     NH         CONCORD
# 30 NaN NaN     NJ         TRENTON
# 31 NaN NaN     NM        SANTA FE
# 32 NaN NaN     NY          ALBANY
# 33 NaN NaN     NC         RALEIGH
# 34 NaN NaN     ND        BISMARCK
# 35 NaN NaN     OH        COLUMBUS
# 36 NaN NaN     OK        OKHALOMA
# 37 NaN NaN     OR           SALEM
# 38 NaN NaN     PA      HARRISBURG
# 39 NaN NaN     RI      PROVIDENCE
# 40 NaN NaN     SC        COLUMBIA
# 41 NaN NaN     SD          PIERRE
# 42 NaN NaN     TN       NASHVILLE
# 43 NaN NaN     TX          AUSTIN
# 44 NaN NaN     UT  SALT LAKE CITY
# 45 NaN NaN     VT     MONTPELLIER
# 46 NaN NaN     VA        RICHMOND
# 47 NaN NaN     WA         OLYMPIA
# 48 NaN NaN     WV      CHARLESTON
# 49 NaN NaN     WI         MADISON
# 50 NaN NaN     WY        CHEYENNE

# %%
#State = State.drop([0,1], axis =1)
State.drop([0,1], axis =1, inplace = True)

# %%
State.columns = State.iloc[0].values

# %%
State= State.drop(0)

# %%
State
# Out:
#    STATE         CAPITAL
# 1     AL      MONTGOMERY
# 2     AK         JUNEAUE
# 3     AZ         PHOENIX
# 4     AR     LITTLE ROCK
# 5     CA      SACRAMENTO
# 6     CO          DENVER
# 7     CT        HARTFORD
# 8     DE           DOVER
# 9     FL     TALLAHASSEE
# 10    GA         ATLANTA
# 11    HI        HONOLOLU
# 12    ID           BOISE
# 13    IL     SPRINGFIELD
# 14    IN    INDIANAPOLIS
# 15    IA      DES MOINES
# 16    KS          TOPEKA
# 17    KY       FRANKFORT
# 18    LA    BATON TROUGE
# 19    ME         AUGUSTA
# 20    MD       ANNAPOLIS
# 21    MA          BOSTON
# 22    MI         LANSING
# 23    MN        ST. PAUL
# 24    MS         JACKSON
# 25    MO  JEFFERSON CITY
# 26    MT          HELENA
# 27    NE         LINCOLN
# 28    NV     CARSON CITY
# 29    NH         CONCORD
# 30    NJ         TRENTON
# 31    NM        SANTA FE
# 32    NY          ALBANY
# 33    NC         RALEIGH
# 34    ND        BISMARCK
# 35    OH        COLUMBUS
# 36    OK        OKHALOMA
# 37    OR           SALEM
# 38    PA      HARRISBURG
# 39    RI      PROVIDENCE
# 40    SC        COLUMBIA
# 41    SD          PIERRE
# 42    TN       NASHVILLE
# 43    TX          AUSTIN
# 44    UT  SALT LAKE CITY
# 45    VT     MONTPELLIER
# 46    VA        RICHMOND
# 47    WA         OLYMPIA
# 48    WV      CHARLESTON
# 49    WI         MADISON
# 50    WY        CHEYENNE

# %%
N_city = df[df["CITY"].isnull()]
N_city
# Out:
#          TRANSACTION_DT                     NAME  \
# 23114        5272015.00        POLSKIN, PHILIPPA
# 64493       11132015.00          SCHOLZ, MELISSA
# 74926       12212015.00  SUN, DANNIENA CHING WAN
# 131535      11062016.00         OLIVIER, WREN I.
# 150039      10292016.00           FARRELL, BRIAN
# ...                 ...                      ...
# 2237853      3082016.00  STOUFFER, SPENCER R. II
# 2395033      4052016.00            WILSON, PEGGY
# 2493765      5272016.00            CHIBBA, SUNIL
# 2537063      5282016.00            RAGIMOV, NARA
# 2551010      1182016.00       WILSON, SEVETRI M.
#
#                                                CAND_NAME  \
# 23114    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 64493    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 74926    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 131535   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 150039   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2237853  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2395033  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2493765  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2537063  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2551010  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                        EMPLOYER                   OCC STATE  \
# 23114    ARTS AND COMMUNICATION COUNSELORS, INC             PRESIDENT    AR
# 64493                      SCHOLZ NONPROFIT LAW              ATTORNEY    WI
# 74926                      LJC INVESTMENTS INC.             PRESIDENT    CA
# 131535                   SELF-EMPLOYED-EMPLOYED                FARMER    VA
# 150039                            VIP MENTORING      VOLUNTEER MENTOR    MI
# ...                                         ...                   ...   ...
# 2237853                   TRAMMELL CROW COMPANY     MANAGING DIRECTOR    VA
# 2395033                                 RETIRED               RETIRED    UT
# 2493765                               HOMEMAKER             HOMEMAKER    GA
# 2537063                        BERGDORF GOODMAN  BRIDAL SALON MANAGER    NY
# 2551010                  SELF-EMPLOYED-EMPLOYED            CONSULTANT    LA
#
#         CAND_PTY_AFFILIATION CITY  TRANSACTION_AMT
# 23114                    DEM  NaN             2700
# 64493                    DEM  NaN              300
# 74926                    DEM  NaN             2700
# 131535                   DEM  NaN               25
# 150039                   DEM  NaN              100
# ...                      ...  ...              ...
# 2237853                  DEM  NaN             1000
# 2395033                  DEM  NaN             1000
# 2493765                  DEM  NaN             2700
# 2537063                  DEM  NaN              500
# 2551010                  DEM  NaN             2700
#
# [87 rows x 9 columns]

# %%
Filter = N_city[N_city["STATE"].isin(State["STATE"])]
Filter.head()
# Out:
#         TRANSACTION_DT                     NAME  \
# 23114       5272015.00        POLSKIN, PHILIPPA
# 64493      11132015.00          SCHOLZ, MELISSA
# 74926      12212015.00  SUN, DANNIENA CHING WAN
# 131535     11062016.00         OLIVIER, WREN I.
# 150039     10292016.00           FARRELL, BRIAN
#
#                                               CAND_NAME  \
# 23114   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 64493   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 74926   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 131535  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 150039  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                       EMPLOYER               OCC STATE  \
# 23114   ARTS AND COMMUNICATION COUNSELORS, INC         PRESIDENT    AR
# 64493                     SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 74926                     LJC INVESTMENTS INC.         PRESIDENT    CA
# 131535                  SELF-EMPLOYED-EMPLOYED            FARMER    VA
# 150039                           VIP MENTORING  VOLUNTEER MENTOR    MI
#
#        CAND_PTY_AFFILIATION CITY  TRANSACTION_AMT
# 23114                   DEM  NaN             2700
# 64493                   DEM  NaN              300
# 74926                   DEM  NaN             2700
# 131535                  DEM  NaN               25
# 150039                  DEM  NaN              100

# %%
Filter.head()
# Out:
#         TRANSACTION_DT                     NAME  \
# 23114       5272015.00        POLSKIN, PHILIPPA
# 64493      11132015.00          SCHOLZ, MELISSA
# 74926      12212015.00  SUN, DANNIENA CHING WAN
# 131535     11062016.00         OLIVIER, WREN I.
# 150039     10292016.00           FARRELL, BRIAN
#
#                                               CAND_NAME  \
# 23114   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 64493   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 74926   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 131535  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 150039  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                       EMPLOYER               OCC STATE  \
# 23114   ARTS AND COMMUNICATION COUNSELORS, INC         PRESIDENT    AR
# 64493                     SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 74926                     LJC INVESTMENTS INC.         PRESIDENT    CA
# 131535                  SELF-EMPLOYED-EMPLOYED            FARMER    VA
# 150039                           VIP MENTORING  VOLUNTEER MENTOR    MI
#
#        CAND_PTY_AFFILIATION CITY  TRANSACTION_AMT
# 23114                   DEM  NaN             2700
# 64493                   DEM  NaN              300
# 74926                   DEM  NaN             2700
# 131535                  DEM  NaN               25
# 150039                  DEM  NaN              100

# %%
Clean = Filter.merge(State, on = "STATE").drop("CITY", axis = 1).rename(columns ={"CAPITAL": "CITY"})
Clean
# Out:
#     TRANSACTION_DT                     NAME  \
# 0       5272015.00        POLSKIN, PHILIPPA
# 1       8152016.00          SHIPMAN, DONALD
# 2      11132015.00          SCHOLZ, MELISSA
# 3       3302016.00          SCHOLZ, MELISSA
# 4      12212015.00  SUN, DANNIENA CHING WAN
# ..             ...                      ...
# 82      2262016.00        JONES, LOUISE NEW
# 83      2262016.00     DAVIS, NATALIE MARIE
# 84      4052016.00            WILSON, PEGGY
# 85      5272016.00            CHIBBA, SUNIL
# 86      1182016.00       WILSON, SEVETRI M.
#
#                                           CAND_NAME  \
# 0   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 3   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 4   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ..                                              ...
# 82  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 83  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 84  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 85  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 86  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                   EMPLOYER               OCC STATE  \
# 0   ARTS AND COMMUNICATION COUNSELORS, INC         PRESIDENT    AR
# 1                       SOUTHWEST AIRLINES  FLIGHT ATTENDANT    AR
# 2                     SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 3                     SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 4                     LJC INVESTMENTS INC.         PRESIDENT    CA
# ..                                     ...               ...   ...
# 82                               HOMEMAKER         HOMEMAKER    AL
# 83             BIRMINGHAM SOUTHERN COLLEGE         PROFESSOR    AL
# 84                                 RETIRED           RETIRED    UT
# 85                               HOMEMAKER         HOMEMAKER    GA
# 86                  SELF-EMPLOYED-EMPLOYED        CONSULTANT    LA
#
#    CAND_PTY_AFFILIATION  TRANSACTION_AMT            CITY
# 0                   DEM             2700     LITTLE ROCK
# 1                   DEM              100     LITTLE ROCK
# 2                   DEM              300         MADISON
# 3                   DEM              200         MADISON
# 4                   DEM             2700      SACRAMENTO
# ..                  ...              ...             ...
# 82                  DEM              500      MONTGOMERY
# 83                  DEM             1500      MONTGOMERY
# 84                  DEM             1000  SALT LAKE CITY
# 85                  DEM             2700         ATLANTA
# 86                  DEM             2700    BATON TROUGE
#
# [87 rows x 9 columns]

# %%
index = df.loc[df["CITY"].isnull()].index

# %%
Clean.index = index
Clean
# Out:
#          TRANSACTION_DT                     NAME  \
# 23114        5272015.00        POLSKIN, PHILIPPA
# 64493        8152016.00          SHIPMAN, DONALD
# 74926       11132015.00          SCHOLZ, MELISSA
# 131535       3302016.00          SCHOLZ, MELISSA
# 150039      12212015.00  SUN, DANNIENA CHING WAN
# ...                 ...                      ...
# 2237853      2262016.00        JONES, LOUISE NEW
# 2395033      2262016.00     DAVIS, NATALIE MARIE
# 2493765      4052016.00            WILSON, PEGGY
# 2537063      5272016.00            CHIBBA, SUNIL
# 2551010      1182016.00       WILSON, SEVETRI M.
#
#                                                CAND_NAME  \
# 23114    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 64493    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 74926    CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 131535   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 150039   CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2237853  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2395033  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2493765  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2537063  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2551010  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
#
#                                        EMPLOYER               OCC STATE  \
# 23114    ARTS AND COMMUNICATION COUNSELORS, INC         PRESIDENT    AR
# 64493                        SOUTHWEST AIRLINES  FLIGHT ATTENDANT    AR
# 74926                      SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 131535                     SCHOLZ NONPROFIT LAW          ATTORNEY    WI
# 150039                     LJC INVESTMENTS INC.         PRESIDENT    CA
# ...                                         ...               ...   ...
# 2237853                               HOMEMAKER         HOMEMAKER    AL
# 2395033             BIRMINGHAM SOUTHERN COLLEGE         PROFESSOR    AL
# 2493765                                 RETIRED           RETIRED    UT
# 2537063                               HOMEMAKER         HOMEMAKER    GA
# 2551010                  SELF-EMPLOYED-EMPLOYED        CONSULTANT    LA
#
#         CAND_PTY_AFFILIATION  TRANSACTION_AMT            CITY
# 23114                    DEM             2700     LITTLE ROCK
# 64493                    DEM              100     LITTLE ROCK
# 74926                    DEM              300         MADISON
# 131535                   DEM              200         MADISON
# 150039                   DEM             2700      SACRAMENTO
# ...                      ...              ...             ...
# 2237853                  DEM              500      MONTGOMERY
# 2395033                  DEM             1500      MONTGOMERY
# 2493765                  DEM             1000  SALT LAKE CITY
# 2537063                  DEM             2700         ATLANTA
# 2551010                  DEM             2700    BATON TROUGE
#
# [87 rows x 9 columns]

# %%
df['CITY'].isna().sum()
# Out:
# 87

# %%
df["CITY"].update(Clean["CITY"])

# %%
m = df[["EMPLOYER", "OCC"]].isna().all(axis = 1)

# %%
##df[df["OCC"].isna()]

# %%
df["CITY"].isnull().sum()
# Out:
# 0

# %%
index = df.loc[df["CITY"].isnull()].fillna(Clean["CITY"]).index

# %%
df = df.rename(columns = {"OCC":"OCCUPATION"})

# %%
df.isnull().sum()
# Out:
# TRANSACTION_DT          0
# NAME                    0
# CAND_NAME               0
# EMPLOYER                0
# OCCUPATION              0
# STATE                   0
# CAND_PTY_AFFILIATION    0
# CITY                    0
# TRANSACTION_AMT         0
# dtype: int64

# %% [markdown]
# # Now The DataFrame is clean and devoid of Mossing Values

# %%
# First, Harmonizing All Trump Name
df[df["NAME"].str.contains("TRUMP, DO")]["NAME"].value_counts().index
df["NAME"] = df["NAME"].replace({k : "DONALD TRUMP" for k in df[df["NAME"].str.contains("TRUMP, DO")]["NAME"].value_counts().index  })

# %%
df
# Out:
#          TRANSACTION_DT                 NAME  \
# 0            6112015.00          ELIAS, JOHN
# 1            6152015.00        CLARY, CAROLE
# 2            4122015.00         FEW, MELANIE
# 3            6132015.00    SPURLOCK, MICHAEL
# 4            6122015.00   SHIFTON, CONSTANCE
# ...                 ...                  ...
# 2664733     10202016.00         FINKEL, MARK
# 2664734     10272016.00         FINKEL, MARK
# 2664735     10072016.00  GERINO, DOROTHY MS.
# 2664736     10032016.00        HEWELL, JAMES
# 2664737     10072016.00  CALDWELL, FRANK MR.
#
#                                                CAND_NAME  \
# 0        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 3        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 4        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2664733             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664734             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664735             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664736             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664737             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                            EMPLOYER                 OCCUPATION STATE  \
# 0        U.S. DEPARTMENT OF JUSTICE                   ATTORNEY    DC
# 1              CPR OF DESTIN,  INC.  VP/DIRECTOR OF OPERATIONS    FL
# 2                  ACE CASH EXPRESS                  MARKETING    TX
# 3                      NOT EMPLOYED               NOT EMPLOYED    TN
# 4            SELF-EMPLOYED-EMPLOYED        EDUCATIONAL ADVISOR    NJ
# ...                             ...                        ...   ...
# 2664733      SELF-EMPLOYED-EMPLOYED                    MANAGER    CO
# 2664734      SELF-EMPLOYED-EMPLOYED                    MANAGER    CO
# 2664735                NOT PROVIDED               NOT PROVIDED    NJ
# 2664736                     RETIRED                    RETIRED    GA
# 2664737                     RETIRED                    RETIRED    AL
#
#         CAND_PTY_AFFILIATION                 CITY  TRANSACTION_AMT
# 0                        DEM           WASHINGTON              100
# 1                        DEM               DESTIN               50
# 2                        DEM               DALLAS                5
# 3                        DEM            NASHVILLE               50
# 4                        DEM          CHERRY HILL               50
# ...                      ...                  ...              ...
# 2664733                  REP    GREENWOOD VILLAGE              240
# 2664734                  REP    GREENWOOD VILLAGE              240
# 2664735                  REP           BELLEVILLE              240
# 2664736                  REP  SAINT SIMONS ISLAND              400
# 2664737                  REP               JASPER              240
#
# [2662041 rows x 9 columns]

# %% [markdown]
# # Converting Transaction date to datetime

# %%
import datetime

# %%
df["TRANSACTION_DT"]= pd.to_datetime(df["TRANSACTION_DT"].astype(int), format= "%m%d%Y")

# %%
df
# Out:
#         TRANSACTION_DT                 NAME  \
# 0           2015-06-11          ELIAS, JOHN
# 1           2015-06-15        CLARY, CAROLE
# 2           2015-04-12         FEW, MELANIE
# 3           2015-06-13    SPURLOCK, MICHAEL
# 4           2015-06-12   SHIFTON, CONSTANCE
# ...                ...                  ...
# 2664733     2016-10-20         FINKEL, MARK
# 2664734     2016-10-27         FINKEL, MARK
# 2664735     2016-10-07  GERINO, DOROTHY MS.
# 2664736     2016-10-03        HEWELL, JAMES
# 2664737     2016-10-07  CALDWELL, FRANK MR.
#
#                                                CAND_NAME  \
# 0        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 1        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 2        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 3        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# 4        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE
# ...                                                  ...
# 2664733             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664734             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664735             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664736             TRUMP, DONALD J. / MICHAEL R. PENCE
# 2664737             TRUMP, DONALD J. / MICHAEL R. PENCE
#
#                            EMPLOYER                 OCCUPATION STATE  \
# 0        U.S. DEPARTMENT OF JUSTICE                   ATTORNEY    DC
# 1              CPR OF DESTIN,  INC.  VP/DIRECTOR OF OPERATIONS    FL
# 2                  ACE CASH EXPRESS                  MARKETING    TX
# 3                      NOT EMPLOYED               NOT EMPLOYED    TN
# 4            SELF-EMPLOYED-EMPLOYED        EDUCATIONAL ADVISOR    NJ
# ...                             ...                        ...   ...
# 2664733      SELF-EMPLOYED-EMPLOYED                    MANAGER    CO
# 2664734      SELF-EMPLOYED-EMPLOYED                    MANAGER    CO
# 2664735                NOT PROVIDED               NOT PROVIDED    NJ
# 2664736                     RETIRED                    RETIRED    GA
# 2664737                     RETIRED                    RETIRED    AL
#
#         CAND_PTY_AFFILIATION                 CITY  TRANSACTION_AMT
# 0                        DEM           WASHINGTON              100
# 1                        DEM               DESTIN               50
# 2                        DEM               DALLAS                5
# 3                        DEM            NASHVILLE               50
# 4                        DEM          CHERRY HILL               50
# ...                      ...                  ...              ...
# 2664733                  REP    GREENWOOD VILLAGE              240
# 2664734                  REP    GREENWOOD VILLAGE              240
# 2664735                  REP           BELLEVILLE              240
# 2664736                  REP  SAINT SIMONS ISLAND              400
# 2664737                  REP               JASPER              240
#
# [2662041 rows x 9 columns]

# %%
mapping = {"REP": "REPUBLICAN",
          "DEM": "DEMOCRAT"}

# %%
df.rename(columns={"CAND_PTY_AFFILIATION": "PARTY", "TRANSACTION_AMT": "CONTRIBUTION"}, inplace = True)

# %%
df["PARTY"] = df["PARTY"].map(mapping)

# %%
cand_mapping = {'TRUMP, DONALD J. / MICHAEL R. PENCE ': "DONALD TRUMP",
               "CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE" : "HILLARY CLINTON"}

df["CAND_NAME"] = df["CAND_NAME"].map(cand_mapping)

# %%
df.head(10)
# Out:
#   TRANSACTION_DT                      NAME        CAND_NAME  \
# 0     2015-06-11               ELIAS, JOHN  HILLARY CLINTON
# 1     2015-06-15             CLARY, CAROLE  HILLARY CLINTON
# 2     2015-04-12              FEW, MELANIE  HILLARY CLINTON
# 3     2015-06-13         SPURLOCK, MICHAEL  HILLARY CLINTON
# 4     2015-06-12        SHIFTON, CONSTANCE  HILLARY CLINTON
# 5     2015-04-14            HARRIS, NICOLE  HILLARY CLINTON
# 6     2015-06-15             GOTTLOB, LYNN  HILLARY CLINTON
# 7     2015-05-20  RAMIREZ-VALLE, FRANCISCO  HILLARY CLINTON
# 8     2015-04-14             VENEGAS, JOHN  HILLARY CLINTON
# 9     2015-06-28           WILLIAMS, DAVID  HILLARY CLINTON
#
#                                  EMPLOYER  \
# 0              U.S. DEPARTMENT OF JUSTICE
# 1                    CPR OF DESTIN,  INC.
# 2                        ACE CASH EXPRESS
# 3                            NOT EMPLOYED
# 4                  SELF-EMPLOYED-EMPLOYED
# 5                               HOMEMAKER
# 6                                 RETIRED
# 7  UNIVERSITY OF CALIFORNIA, SAN FRANCISC
# 8                                 RETIRED
# 9              OHIO EDUCATION ASSOCIATION
#
#                                OCCUPATION STATE     PARTY           CITY  \
# 0                                ATTORNEY    DC  DEMOCRAT     WASHINGTON
# 1               VP/DIRECTOR OF OPERATIONS    FL  DEMOCRAT         DESTIN
# 2                               MARKETING    TX  DEMOCRAT         DALLAS
# 3                            NOT EMPLOYED    TN  DEMOCRAT      NASHVILLE
# 4                     EDUCATIONAL ADVISOR    NJ  DEMOCRAT    CHERRY HILL
# 5                               HOMEMAKER    NY  DEMOCRAT       NEW YORK
# 6                                 RETIRED    OH  DEMOCRAT      BEACHWOOD
# 7                           DERMATOLOGIST    CA  DEMOCRAT  SAN FRANCISCO
# 8                                 RETIRED    CA  DEMOCRAT     CHATSWORTH
# 9  DIRECTOR OF GOVERNMENT RELATIONS & COM    MD  DEMOCRAT       BETHESDA
#
#    CONTRIBUTION
# 0           100
# 1            50
# 2             5
# 3            50
# 4            50
# 5           100
# 6           100
# 7            50
# 8            25
# 9            50

# %%
df.index = range(2662041)

# %%
pd.set_option("precision", 2)

# %% [markdown]
# # CONTRIBUTION BY PARTY

# %%
CONTRIB_BY_PARTY = df.groupby(["CAND_NAME","PARTY"])[["CONTRIBUTION"]].sum().reset_index()
CONTRIB_BY_PARTY
# Out:
#          CAND_NAME       PARTY  CONTRIBUTION
# 0     DONALD TRUMP  REPUBLICAN      76771555
# 1  HILLARY CLINTON    DEMOCRAT     293998038

# %%
CONTRIB_BY_PARTY["PERCENTAGE"] = CONTRIB_BY_PARTY["CONTRIBUTION"]/(CONTRIB_BY_PARTY["CONTRIBUTION"]).sum()

# %%
CONTRIB_BY_PARTY
# Out:
#          CAND_NAME       PARTY  CONTRIBUTION  PERCENTAGE
# 0     DONALD TRUMP  REPUBLICAN      76771555        0.21
# 1  HILLARY CLINTON    DEMOCRAT     293998038        0.79

# %%
import seaborn as sb

# %%
sb.barplot(x= "PARTY", y="PERCENTAGE", data = CONTRIB_BY_PARTY)
plt.title("Contriution by party", size = 18)
# Out:
# Text(0.5, 1.0, 'Contriution by party')

# %% [markdown]
# # CONTRIBUTION BY EMPLOYER

# %%
Top_10_Cont = df.groupby("NAME").size().nlargest(10)
Top_10_index = Top_10_Cont.index

# %%
df["CONTRIBUTION"] = df["CONTRIBUTION"].astype(int)

# %%
Cont_by_Employer = df.pivot_table(values = "CONTRIBUTION", index = [ "EMPLOYER"], columns = "CAND_NAME", aggfunc = "sum")

# %%
Cont_by_Employer
# Out:
# CAND_NAME                             DONALD TRUMP  HILLARY CLINTON
# EMPLOYER
#   NEDERLAND INDEPENDENT SCHOOL DIST.           NaN            25.00
#  AB CONSULTANTS, INC                           NaN            37.00
#  APPLE INC.                                    NaN           380.00
#  HOME CHILD CARE EDUCATOR                      NaN           111.00
#  JOHN L. SPIEGELMAN TYPE & TEXT                NaN           177.00
# ...                                            ...              ...
# ZZUBCO, INC.                                   NaN            25.00
# [24]7 INC.                                     NaN            55.00
# [BANK]                                         NaN           152.00
# [BLANK                                         NaN            19.00
# `GRANITE                                    100.00              NaN
#
# [159319 rows x 2 columns]

# %%
Top_Employers.sum(axis = 1).plot.barh(figsize = (12,8))
plt.title
plt.ticklabel_format(style='plain', axis = "x")

# %%
Top_10_Employer = df.groupby("EMPLOYER").size().nlargest(10)
Top_10_Employer_index = Top_10_Employer.index

# %% [markdown]
# # Top Ten Contributors by employers and candidates

# %%
Top_Employers = Cont_by_Employer.loc[Top_10_Employer_index]
Top_Employers
# Out:
# CAND_NAME               DONALD TRUMP  HILLARY CLINTON
# EMPLOYER
# RETIRED                  16126292.00      54875965.00
# SELF-EMPLOYED-EMPLOYED    7461393.00      40656560.00
# HOMEMAKER                 5409864.00      18110285.00
# NOT EMPLOYED                82685.00       7883626.00
# DISABLED                     1418.00        299281.00
# NOT AVAILABLE               86614.00       1528323.00
# GOOGLE                       9700.00       1023681.00
# U.S. GOVERNMENT              7610.00        403555.00
# NOT PROVIDED              1764424.00         39995.00
# IBM                         19583.00        242055.00

# %% [markdown]
# # Top Employers Contribution by Proportion

# %%
Top_Employers.div(Top_Employers.sum(1), axis = 0).plot(kind = "barh", figsize = (12,8))
plt.legend(loc = 4)

# %% [markdown]
# # CONTRIBUTION BY OCCUPATION

# %%
df["OCCUPATION"] = df["OCCUPATION"].str.replace("SELF EMPLOYED", "SELF-EMPLOYED")

# %% [markdown]
# # Top Ten Contribution by Occupation

# %%
df.columns
# Out:
# Index(['TRANSACTION_DT', 'NAME', 'CAND_NAME', 'EMPLOYER', 'OCCUPATION',
#        'STATE', 'PARTY', 'CITY', 'CONTRIBUTION'],
#       dtype='object')

# %%
df.groupby("OCCUPATION")[["CONTRIBUTION"]].sum().sort_values(by = "CONTRIBUTION", ascending = False)[:10]
# Out:
#                CONTRIBUTION
# OCCUPATION
# RETIRED            62413642
# ATTORNEY           26572403
# HOMEMAKER          23878979
# PRESIDENT/CEO      18822137
# PHYSICIAN           8650140
# CONSULTANT          8009613
# LAWYER              7979266
# CEO                 6440474
# PROFESSOR           5412553
# PRESIDENT           4952688

# %%
df.groupby("OCCUPATION")[["CONTRIBUTION"]].sum().sort_values(by = "CONTRIBUTION", ascending = False)[:10].plot.barh(legend = None, color  = "#4169E1", figsize = (12,8) )
plt.title("Top Ten Contribution by Occupation", size = 25)
# Out:
# Text(0.5, 1.0, 'Top Ten Contribution by Occupation')

# %% [markdown]
# # Top 15 Cntrubutions by Occupations and Candidates

# %%
by_OCCUPATION= df.groupby(["CAND_NAME", "OCCUPATION"])[['CONTRIBUTION']].sum().reset_index()
by_OCCUPATION = by_OCCUPATION[by_OCCUPATION.sum(1)>100000].nlargest(15, columns = "CONTRIBUTION")
by_OCCUPATION
# Out:
#              CAND_NAME     OCCUPATION  CONTRIBUTION
# 51455  HILLARY CLINTON        RETIRED      46289067
# 19666  HILLARY CLINTON       ATTORNEY      25844443
# 11470     DONALD TRUMP  PRESIDENT/CEO      18676244
# 36618  HILLARY CLINTON      HOMEMAKER      18432784
# 12811     DONALD TRUMP        RETIRED      16124575
# 39369  HILLARY CLINTON         LAWYER       7760708
# 25193  HILLARY CLINTON     CONSULTANT       7622214
# 46119  HILLARY CLINTON      PHYSICIAN       7431660
# 6813      DONALD TRUMP      HOMEMAKER       5446195
# 48091  HILLARY CLINTON      PROFESSOR       5359174
# 22125  HILLARY CLINTON            CEO       5287522
# 47040  HILLARY CLINTON      PRESIDENT       4070940
# 43745  HILLARY CLINTON   NOT EMPLOYED       3918183
# 32159  HILLARY CLINTON      EXECUTIVE       3081231
# 58159  HILLARY CLINTON        TEACHER       3070208

# %%
plt.figure(figsize = (12,8))
sb.barplot(x="CONTRIBUTION", y = "OCCUPATION", hue = "CAND_NAME", data = by_OCCUPATION)  
plt.legend(loc = 4)
plt.ticklabel_format(style='plain', axis = "x")

# %% [markdown]
# # CONTRIBUTION BY STATE

# %%
df.groupby("STATE")[["CONTRIBUTION"]].sum().sort_values(by = "CONTRIBUTION", ascending = False)[:10]
# Out:
#        CONTRIBUTION
# STATE
# CA         70861488
# NY         65846367
# TX         23385517
# FL         21779524
# MA         14517436
# IL         12877689
# VA         11512102
# MD         11324742
# DC         11245376
# PA         10233809

# %% [markdown]
# # Top Ten Contribution by State

# %%
df.groupby("STATE")[["CONTRIBUTION"]].sum().sort_values(by = "CONTRIBUTION", ascending = False)[:10].plot(kind = "bar",  figsize =  (12,8), 
                                                                                                          legend = None, color = "#00BFFF", alpha = 0.95 )
plt.title("Top Ten Contribution by State", size = 25)
plt.ticklabel_format(style='plain', axis = "y")

# %% [markdown]
#  Califrnia received the Highest Contributions

# %% [markdown]
# # Contribution by State and candidates

# %%
State_Prop = by_STATE.unstack(0).loc[df.groupby("STATE")[["CONTRIBUTION"]].sum().sort_values(by = "CONTRIBUTION", ascending = False)[:10].index]

# %%
State_Prop.columns = ["DONALD TRUMP", "HILLARY CLINTON"]

# %%
State_Prop.div(State_Prop.sum(axis = 1), axis = 0)
# Out:
#        DONALD TRUMP  HILLARY CLINTON
# STATE
# CA             0.09             0.91
# NY             0.33             0.67
# TX             0.31             0.69
# FL             0.30             0.70
# MA             0.07             0.93
# IL             0.12             0.88
# VA             0.16             0.84
# MD             0.08             0.92
# DC             0.01             0.99
# PA             0.18             0.82

# %%
State_Prop.plot(kind = "bar", figsize = (12,8))
plt.title("Contributions by states per Candidates", size = 18)
plt.ticklabel_format(style='plain', axis = "y")

# %%
mapping = {"OWNER": "BUSINESS OWNER"}
df["EMPLOYER"] =df["EMPLOYER"].map(lambda x: mapping.get(x,x))
df["EMPLOYER"][df["EMPLOYER"].str.contains("OWNER")]
# Out:
# 3703            CIRCLE C HOME OWNERS ASSOCIATION
# 7122            CIRCLE C HOME OWNERS ASSOCIATION
# 11718           CIRCLE C HOME OWNERS ASSOCIATION
# 11966           CIRCLE C HOME OWNERS ASSOCIATION
# 17205                             BUSINESS OWNER
#                            ...
# 2660043                           BUSINESS OWNER
# 2660152                           BUSINESS OWNER
# 2660153                           BUSINESS OWNER
# 2660156                           BUSINESS OWNER
# 2661872    OWNER E. AMBOY SPRINKLER SYSTEMS INC.
# Name: EMPLOYER, Length: 1641, dtype: object

# %%
Emp_map = {"SELF-EMPLOYED-EMPLOYED": "SELF-EMPLOYED",
          "SELF-EMPLOYED EMPLOYED": "SELF-EMPLOYED"}

# %%
df["EMPLOYER"] = df["EMPLOYER"].map(lambda x: Emp_map.get(x,x))

# %%
by_EMPLOYER = df.groupby(["CAND_NAME", "EMPLOYER"])["CONTRIBUTION"].sum()
by_EMPLOYER = by_EMPLOYER[by_EMPLOYER>100000]
by_EMPLOYER = EMPLOYER = pd.DataFrame(by_EMPLOYER)
by_EMPLOYER
# Out:
#                                           CONTRIBUTION
# CAND_NAME       EMPLOYER
# DONALD TRUMP    ATTORNEY                        130120
#                 BUSINESS OWNER                  480601
#                 CEO                             180815
#                 ENTREPRENEUR                    404951
#                 HOMEMAKER                      5409864
# ...                                                ...
# HILLARY CLINTON UNIVERSITY OF WASHINGTON        153876
#                 VERIZON                         146431
#                 WELLS FARGO                     232990
#                 WILMERHALE, LLP                 115510
#                 YALE UNIVERSITY                 239860
#
# [95 rows x 1 columns]

# %% [markdown]
# # Top Ten Contributions By employers and Candidate

# %%
by_EMPLOYER = by_EMPLOYER.reset_index().groupby(["CAND_NAME"]).apply(lambda Group: Group.sort_values(by = "CONTRIBUTION", ascending = False)[:10]).reset_index(drop=True)

# %%
by_EMPLOYER
# Out:
#           CAND_NAME                EMPLOYER  CONTRIBUTION
# 0      DONALD TRUMP  THE TRUMP ORGANIZATION      18633407
# 1      DONALD TRUMP                 RETIRED      16126292
# 2      DONALD TRUMP           SELF-EMPLOYED       7776589
# 3      DONALD TRUMP               HOMEMAKER       5409864
# 4      DONALD TRUMP            NOT PROVIDED       1764424
# 5      DONALD TRUMP          BUSINESS OWNER        480601
# 6      DONALD TRUMP            ENTREPRENEUR        404951
# 7      DONALD TRUMP               PHYSICIAN        206345
# 8      DONALD TRUMP                     CEO        180815
# 9      DONALD TRUMP               PRESIDENT        161207
# 10  HILLARY CLINTON                 RETIRED      54875965
# 11  HILLARY CLINTON           SELF-EMPLOYED      41947587
# 12  HILLARY CLINTON               HOMEMAKER      18110285
# 13  HILLARY CLINTON            NOT EMPLOYED       7883626
# 14  HILLARY CLINTON           NOT AVAILABLE       1528323
# 15  HILLARY CLINTON                  GOOGLE       1023681
# 16  HILLARY CLINTON     STANFORD UNIVERSITY        422284
# 17  HILLARY CLINTON               MICROSOFT        405239
# 18  HILLARY CLINTON         U.S. GOVERNMENT        403555
# 19  HILLARY CLINTON         MORGAN & MORGAN        384308

# %%
mapping = {"BUSINESS BUSINESS OWNER": "BUSINESS OWNER"}
by_EMPLOYER["EMPLOYER"].map(lambda x: mapping.get(x,x))
# Out:
# 0     THE TRUMP ORGANIZATION
# 1                    RETIRED
# 2              SELF-EMPLOYED
# 3                  HOMEMAKER
# 4               NOT PROVIDED
# 5             BUSINESS OWNER
# 6               ENTREPRENEUR
# 7                  PHYSICIAN
# 8                        CEO
# 9                  PRESIDENT
# 10                   RETIRED
# 11             SELF-EMPLOYED
# 12                 HOMEMAKER
# 13              NOT EMPLOYED
# 14             NOT AVAILABLE
# 15                    GOOGLE
# 16       STANFORD UNIVERSITY
# 17                 MICROSOFT
# 18           U.S. GOVERNMENT
# 19           MORGAN & MORGAN
# Name: EMPLOYER, dtype: object

# %%
by_EMPLOYER
# Out:
#           CAND_NAME                EMPLOYER  CONTRIBUTION
# 0      DONALD TRUMP  THE TRUMP ORGANIZATION      18633407
# 1      DONALD TRUMP                 RETIRED      16126292
# 2      DONALD TRUMP           SELF-EMPLOYED       7776589
# 3      DONALD TRUMP               HOMEMAKER       5409864
# 4      DONALD TRUMP            NOT PROVIDED       1764424
# 5      DONALD TRUMP          BUSINESS OWNER        480601
# 6      DONALD TRUMP            ENTREPRENEUR        404951
# 7      DONALD TRUMP               PHYSICIAN        206345
# 8      DONALD TRUMP                     CEO        180815
# 9      DONALD TRUMP               PRESIDENT        161207
# 10  HILLARY CLINTON                 RETIRED      54875965
# 11  HILLARY CLINTON           SELF-EMPLOYED      41947587
# 12  HILLARY CLINTON               HOMEMAKER      18110285
# 13  HILLARY CLINTON            NOT EMPLOYED       7883626
# 14  HILLARY CLINTON           NOT AVAILABLE       1528323
# 15  HILLARY CLINTON                  GOOGLE       1023681
# 16  HILLARY CLINTON     STANFORD UNIVERSITY        422284
# 17  HILLARY CLINTON               MICROSOFT        405239
# 18  HILLARY CLINTON         U.S. GOVERNMENT        403555
# 19  HILLARY CLINTON         MORGAN & MORGAN        384308

# %%
plt.figure(figsize = (12,8))
sb.barplot(x= "CONTRIBUTION", y= "EMPLOYER", hue = "CAND_NAME", data= by_EMPLOYER )
plt.ticklabel_format(style='plain', axis = "x")
plt.legend(loc = 4)

# %% [markdown]
# # CONTRIBUTIONS BY INDIVIDUAL

# %%
Top_10_Contributors = df.groupby("NAME").size().nlargest(10)
Top_10_Contributors_index = Top_10_Contributors.index

# %%
df.groupby("NAME")[["CONTRIBUTION"]].sum().sort_values(ascending = False, by = "CONTRIBUTION")
# Out:
#                            CONTRIBUTION
# NAME
# DONALD TRUMP                   18633157
# CLINTON, HILLARY RODHAM         1450306
# BOCH, ERNIE                      171172
# TREIBEL, RANDY                    52352
# SMITH, JAMES                      42363
# ...                                 ...
# WESTCOTT, JANET                       1
# JENNINGS, MARY RUTHERFORD             1
# DEGNEN, CAROL                         1
# MCDAVIT, JANICE                       1
# SHEFFIELD, ASHLEY                     1
#
# [455239 rows x 1 columns]

# %% [markdown]
# # Top 20 Largets Occupation Contributions by candidates

# %%
index = df.groupby("OCCUPATION").size().nlargest(20).index

# %%
by_CANDIDATES = OCC.loc[index]
by_CANDIDATES
# Out:
# CAND_NAME          DONALD TRUMP  HILLARY CLINTON
# OCCUPATION
# RETIRED             16124575.00      46289067.00
# ATTORNEY              727960.00      25844443.00
# HOMEMAKER            5446195.00      18432784.00
# TEACHER                85044.00       3070208.00
# PROFESSOR              53379.00       5359174.00
# PHYSICIAN            1218480.00       7431660.00
# NOT EMPLOYED           78418.00       3918183.00
# CONSULTANT            387399.00       7622214.00
# LAWYER                218558.00       7760708.00
# MANAGER               585766.00       2451993.00
# WRITER                 32083.00       2670646.00
# ENGINEER              646898.00       2254465.00
# SALES                 723267.00       1290821.00
# STUDENT                50049.00       2322204.00
# REGISTERED NURSE       49378.00        624929.00
# EDUCATOR               17321.00        987579.00
# OWNER                 937096.00       2888911.00
# SOFTWARE ENGINEER      91292.00       1572497.00
# PSYCHOLOGIST           25110.00       1188787.00
# CEO                  1152952.00       5287522.00

# %%
by_CANDIDATES.plot.barh(figsize = ((12,8)), stacked = True)
plt.title("20 largest contribution by candidates and occupation", size  = 22)
plt.ticklabel_format(style='plain', axis = "x")

# %%
CAND_PROP = by_CANDIDATES.div(by_CANDIDATES.sum(1), axis = 0)
CAND_PROP.stack()
CAND_PROP = pd.DataFrame(CAND_PROP.stack())
CAND_PROP = CAND_PROP.rename(columns ={0:"Percentage"})

# %%
CAND_PROP = CAND_PROP.reset_index()
CAND_PROP
# Out:
#            OCCUPATION        CAND_NAME  Percentage
# 0             RETIRED     DONALD TRUMP        0.26
# 1             RETIRED  HILLARY CLINTON        0.74
# 2            ATTORNEY     DONALD TRUMP        0.03
# 3            ATTORNEY  HILLARY CLINTON        0.97
# 4           HOMEMAKER     DONALD TRUMP        0.23
# 5           HOMEMAKER  HILLARY CLINTON        0.77
# 6             TEACHER     DONALD TRUMP        0.03
# 7             TEACHER  HILLARY CLINTON        0.97
# 8           PROFESSOR     DONALD TRUMP        0.01
# 9           PROFESSOR  HILLARY CLINTON        0.99
# 10          PHYSICIAN     DONALD TRUMP        0.14
# 11          PHYSICIAN  HILLARY CLINTON        0.86
# 12       NOT EMPLOYED     DONALD TRUMP        0.02
# 13       NOT EMPLOYED  HILLARY CLINTON        0.98
# 14         CONSULTANT     DONALD TRUMP        0.05
# 15         CONSULTANT  HILLARY CLINTON        0.95
# 16             LAWYER     DONALD TRUMP        0.03
# 17             LAWYER  HILLARY CLINTON        0.97
# 18            MANAGER     DONALD TRUMP        0.19
# 19            MANAGER  HILLARY CLINTON        0.81
# 20             WRITER     DONALD TRUMP        0.01
# 21             WRITER  HILLARY CLINTON        0.99
# 22           ENGINEER     DONALD TRUMP        0.22
# 23           ENGINEER  HILLARY CLINTON        0.78
# 24              SALES     DONALD TRUMP        0.36
# 25              SALES  HILLARY CLINTON        0.64
# 26            STUDENT     DONALD TRUMP        0.02
# 27            STUDENT  HILLARY CLINTON        0.98
# 28   REGISTERED NURSE     DONALD TRUMP        0.07
# 29   REGISTERED NURSE  HILLARY CLINTON        0.93
# 30           EDUCATOR     DONALD TRUMP        0.02
# 31           EDUCATOR  HILLARY CLINTON        0.98
# 32              OWNER     DONALD TRUMP        0.24
# 33              OWNER  HILLARY CLINTON        0.76
# 34  SOFTWARE ENGINEER     DONALD TRUMP        0.05
# 35  SOFTWARE ENGINEER  HILLARY CLINTON        0.95
# 36       PSYCHOLOGIST     DONALD TRUMP        0.02
# 37       PSYCHOLOGIST  HILLARY CLINTON        0.98
# 38                CEO     DONALD TRUMP        0.18
# 39                CEO  HILLARY CLINTON        0.82

# %%
sb.set(rc = {"figure.figsize":(10.5, 10.2)})

# %%
plt.figure(figsize = (12,8))
sb.barplot(y = "OCCUPATION", x = "Percentage", hue = "CAND_NAME", data = CAND_PROP)
plt.title("20 largest contribution by candidates  and occupation proportion", size  = 18)
# Out:
# Text(0.5, 1.0, '20 largest contribution by candidates  and occupation proportion')

# %%
by_DATE = df.pivot_table(index = "TRANSACTION_DT", columns = ["CAND_NAME"], values = "CONTRIBUTION", aggfunc = "sum")

# %% [markdown]
# # Monthly Contributions by Candidates

# %%
by_DATE
# Out:
# CAND_NAME       DONALD TRUMP  HILLARY CLINTON
# TRANSACTION_DT
# 2015-04-07               NaN         18900.00
# 2015-04-10               NaN          2700.00
# 2015-04-11               NaN             6.00
# 2015-04-12               NaN       1417792.00
# 2015-04-13               NaN       1317243.00
# ...                      ...              ...
# 2016-12-27           9685.00          2662.00
# 2016-12-28          13460.00           435.00
# 2016-12-29          10985.00           998.00
# 2016-12-30          12234.00           743.00
# 2016-12-31           4300.00           300.00
#
# [606 rows x 2 columns]

# %%
by_DATE = by_DATE.resample("MS").sum()

by_DATE
# Out:
# CAND_NAME       DONALD TRUMP  HILLARY CLINTON
# TRANSACTION_DT
# 2015-04-01              0.00      13477753.00
# 2015-05-01              0.00      12078526.00
# 2015-06-01          65224.00      14059520.00
# 2015-07-01         264742.00       7138019.00
# 2015-08-01         630093.00       5916333.00
# 2015-09-01         343798.00       9849395.00
# 2015-10-01         236968.00       7898924.00
# 2015-11-01         160560.00       8880140.00
# 2015-12-01         284979.00       8490060.00
# 2016-01-01          23959.00       1074214.00
# 2016-02-01         494766.00      13303220.00
# 2016-03-01         737758.00      12597862.00
# 2016-04-01         482816.00      15069797.00
# 2016-05-01        1221601.00      15232914.00
# 2016-06-01        9943013.00      18100364.00
# 2016-07-01       11413799.00      20213582.00
# 2016-08-01        8503518.00      18967363.00
# 2016-09-01        8127515.00      29340425.00
# 2016-10-01       28994319.00      37463189.00
# 2016-11-01        3742186.00      21898180.00
# 2016-12-01        1099941.00       2948258.00

# %%
by_DATE.plot(color = ["blue", "green"])
plt.title("Monthly Contributions by Candidates", size = 18)

plt.ticklabel_format(style='plain', axis = "y")

# %%
fig, axes = plt.subplots(1,2, figsize = ((12,9)), dpi = 90)
by_DATE["DONALD TRUMP"].plot(ax = axes[0], title = "DONALD TRUMP MONTHLY CONTRIBUTION VARIATION", color = "blue")
axes[0].ticklabel_format(style='plain', axis = "y")
by_DATE["HILLARY CLINTON"].plot(ax = axes[1], title = "HILLARY CLINTON MONTHLY CONTRIBUTIOIN VARIATION", color = "red")
axes[1].ticklabel_format(style='plain', axis = "y")
plt.subplots_adjust(bottom = 0.5, wspace = 0.5 )

# %% [markdown]
# # TOP INDIVIDUAL CONTRIBUTIONS

# %%
by_NAME = df.groupby(["NAME", "PARTY"])["CONTRIBUTION"].sum()
by_NAME = pd.DataFrame(by_NAME)
#by_NAME.reset_index().groupby("NAME").apply(lambda group: group.nlargest(5, columns = "CONTRIBUTION"))
by_NAME
# Out:
#                                        CONTRIBUTION
# NAME                       PARTY
#  ALERIS, ANNAKIM           DEMOCRAT             150
#  CALVEY, DONNA MORRIS      DEMOCRAT             200
#  ESCOHIER, ROSARY          DEMOCRAT             175
#  KORNBERG, DONNA HABER     DEMOCRAT             100
#  LEIGHTON, CHARLOTTE TROUP DEMOCRAT             200
# ...                                             ...
# ZYSMAN, JOHN               DEMOCRAT             100
# ZYSMAN-CROMWELL, ALICIA    DEMOCRAT             200
# ZYTNICK, JONATHON          DEMOCRAT             100
# ZYVOLOSKI, LAUREL          DEMOCRAT              54
# ZYWICIEL, ROBERT           REPUBLICAN          2700
#
# [465261 rows x 1 columns]

# %%
#by_NAME.reset_index().groupby("NAME").apply(lambda group: group.sort_values(by = "CONTRIBUTION", ascending = False)[:5])

# %% [markdown]
# # Top  50 Individual Contributors

# %%
Best = by_NAME.sort_values(by="CONTRIBUTION", ascending = False)[:50].reset_index()
Best
# Out:
#                        NAME       PARTY  CONTRIBUTION
# 0              DONALD TRUMP  REPUBLICAN      18633157
# 1   CLINTON, HILLARY RODHAM    DEMOCRAT       1450306
# 2               BOCH, ERNIE  REPUBLICAN        171172
# 3            TREIBEL, RANDY  REPUBLICAN         52352
# 4             HAMLIN, TRISH  REPUBLICAN         38400
# 5        RUNYAN, R. BRADLEY    DEMOCRAT         35100
# 6              HYDE, ROBERT  REPUBLICAN         34085
# 7            SMITH, MICHAEL    DEMOCRAT         33909
# 8         FRIEDMAN, JANELLE    DEMOCRAT         32400
# 9             BURNS, URSULA    DEMOCRAT         32400
# 10           ELLING, MARTIN    DEMOCRAT         32399
# 11          WILLIAMS, DAVID  REPUBLICAN         29572
# 12             COHEN, DAVID    DEMOCRAT         27459
# 13             SMITH, JAMES  REPUBLICAN         26818
# 14           GIGANTE, PETER  REPUBLICAN         26300
# 15           BROWN, MICHAEL    DEMOCRAT         25903
# 16             SMITH, DAVID    DEMOCRAT         24613
# 17            BARRETT, NOEL  REPUBLICAN         24300
# 18         PALATCHI, ROBERT  REPUBLICAN         24132
# 19    CIEPIELOWSKI, MATTHEW  REPUBLICAN         23730
# 20         RITCHIE, CHARLES  REPUBLICAN         23545
# 21            ASHFORD, ALEX  REPUBLICAN         23044
# 22            RYAN, MICHAEL  REPUBLICAN         22800
# 23            MILLER, DAVID    DEMOCRAT         22728
# 24               KHAN, FAIZ  REPUBLICAN         22600
# 25            KENT, BEVERLY  REPUBLICAN         22400
# 26              MOORE, JOHN    DEMOCRAT         22321
# 27          GUTTMAN, AMANDA    DEMOCRAT         21846
# 28             JONES, JAMES    DEMOCRAT         21774
# 29              LEE, ROBERT    DEMOCRAT         21630
# 30            KATS, BRANDON  REPUBLICAN         21600
# 31              STEIN, MARK    DEMOCRAT         21555
# 32             JONES, DAVID    DEMOCRAT         20663
# 33           KRAMER, ANDREA    DEMOCRAT         20500
# 34            TOMBUL, TURAN    DEMOCRAT         20500
# 35           SMITH, WILLIAM    DEMOCRAT         20471
# 36             SMITH, LINDA    DEMOCRAT         20463
# 37             DAVIS, JAMES    DEMOCRAT         20449
# 38        GOCKE, THOMAS DR.    DEMOCRAT         20000
# 39            GOCKE, THOMAS    DEMOCRAT         20000
# 40            MILLER, SUSAN    DEMOCRAT         19973
# 41         JOHNSON, WILLIAM    DEMOCRAT         19591
# 42              JOBE, RENEE  REPUBLICAN         19550
# 43             BROWN, DAVID    DEMOCRAT         18975
# 44         CARRUTHERS, SARA  REPUBLICAN         18895
# 45          COHEN, JONATHAN    DEMOCRAT         18387
# 46            KAPOOR, VIKAS    DEMOCRAT         18200
# 47           JOHNSON, JAMES    DEMOCRAT         17806
# 48          JOHNSON, ROBERT    DEMOCRAT         17665
# 49            EVANS, ROBERT    DEMOCRAT         17630

# %%
sb.barplot(x = "CONTRIBUTION", y = "NAME", hue = "PARTY", data = Best[2:])
plt.ticklabel_format(style='plain', axis = "x")

# %% [markdown]
# # Top 5 individual Contributors by Party to the Two Candidates

# %%
by_NAME = by_NAME[by_NAME.sum(1)>10000].sort_values(ascending = False, by = "CONTRIBUTION")

# %%
by_NAME
# Out:
#                                     CONTRIBUTION
# NAME                    PARTY
# DONALD TRUMP            REPUBLICAN      18633157
# CLINTON, HILLARY RODHAM DEMOCRAT         1450306
# BOCH, ERNIE             REPUBLICAN        171172
# TREIBEL, RANDY          REPUBLICAN         52352
# HAMLIN, TRISH           REPUBLICAN         38400
# ...                                          ...
# MILLER, MICHAEL         DEMOCRAT           10023
# BRUSTIN, MICHELE        DEMOCRAT           10020
# ARNOLD, STEVE           REPUBLICAN         10020
# STERN, DAVID            DEMOCRAT           10017
# FOX, JOHN               REPUBLICAN         10007
#
# [412 rows x 1 columns]

# %%
Major_Contributors = by_NAME.reset_index().groupby("PARTY").apply(lambda group: group.sort_values(by = "CONTRIBUTION", ascending = False)[:6]).reset_index(drop = True).set_index("NAME")

# %%
Major_Contributors
# Out:
#                               PARTY  CONTRIBUTION
# NAME
# CLINTON, HILLARY RODHAM    DEMOCRAT       1450306
# RUNYAN, R. BRADLEY         DEMOCRAT         35100
# SMITH, MICHAEL             DEMOCRAT         33909
# FRIEDMAN, JANELLE          DEMOCRAT         32400
# BURNS, URSULA              DEMOCRAT         32400
# ELLING, MARTIN             DEMOCRAT         32399
# DONALD TRUMP             REPUBLICAN      18633157
# BOCH, ERNIE              REPUBLICAN        171172
# TREIBEL, RANDY           REPUBLICAN         52352
# HAMLIN, TRISH            REPUBLICAN         38400
# HYDE, ROBERT             REPUBLICAN         34085
# WILLIAMS, DAVID          REPUBLICAN         29572

# %%
Hillary = Major_Contributors[:6]
Hillary
# Out:
#                             PARTY  CONTRIBUTION
# NAME
# CLINTON, HILLARY RODHAM  DEMOCRAT       1450306
# RUNYAN, R. BRADLEY       DEMOCRAT         35100
# SMITH, MICHAEL           DEMOCRAT         33909
# FRIEDMAN, JANELLE        DEMOCRAT         32400
# BURNS, URSULA            DEMOCRAT         32400
# ELLING, MARTIN           DEMOCRAT         32399

# %%
Trump = Major_Contributors[6:]
Trump
# Out:
#                       PARTY  CONTRIBUTION
# NAME
# DONALD TRUMP     REPUBLICAN      18633157
# BOCH, ERNIE      REPUBLICAN        171172
# TREIBEL, RANDY   REPUBLICAN         52352
# HAMLIN, TRISH    REPUBLICAN         38400
# HYDE, ROBERT     REPUBLICAN         34085
# WILLIAMS, DAVID  REPUBLICAN         29572

# %%
Hillary[1:]
# Out:
#                        PARTY  CONTRIBUTION
# NAME
# RUNYAN, R. BRADLEY  DEMOCRAT         35100
# SMITH, MICHAEL      DEMOCRAT         33909
# FRIEDMAN, JANELLE   DEMOCRAT         32400
# BURNS, URSULA       DEMOCRAT         32400
# ELLING, MARTIN      DEMOCRAT         32399

# %%
fig, axes = plt.subplots(1,2, figsize = ((12,8)), dpi = 70)

sb.barplot(ax=axes[0], y = Hillary[1:].index, x = "CONTRIBUTION", data = Hillary[1:])
sb.barplot(ax=axes[1], y = Trump[1:].index, x = "CONTRIBUTION", data = Trump[1:])

axes[0].ticklabel_format(style='plain', axis = "x")
axes[1].ticklabel_format(style='plain', axis = "x")
fig.subplots_adjust(wspace = 0.8)


#Major_Contributors

# %% [markdown]
# # Contributions By Range of Values

# %%
bins = [1, 10, 100, 1000, 10000, 100000, np.inf]
labels = ["below 10", "btw 10 and 100", "btw 100 and 1000", "btw 1000 and 10000", "btw 10000 and 100000", "abv 100000" ]

# %%
Range = pd.cut(df["CONTRIBUTION"], bins = bins, labels = labels)
Range
# Out:
# 0            btw 10 and 100
# 1            btw 10 and 100
# 2                  below 10
# 3            btw 10 and 100
# 4            btw 10 and 100
#                  ...
# 2662036    btw 100 and 1000
# 2662037    btw 100 and 1000
# 2662038    btw 100 and 1000
# 2662039    btw 100 and 1000
# 2662040    btw 100 and 1000
# Name: CONTRIBUTION, Length: 2662041, dtype: category
# Categories (6, object): ['below 10' < 'btw 10 and 100' < 'btw 100 and 1000' < 'btw 1000 and 10000' < 'btw 10000 and 100000' < 'abv 100000']

# %%
Range = df.groupby([Range, "CAND_NAME"])["CONTRIBUTION"].sum()

# %%
Range = pd.DataFrame(Range)
Range
# Out:
#                                       CONTRIBUTION
# CONTRIBUTION         CAND_NAME
# below 10             DONALD TRUMP            14407
#                      HILLARY CLINTON       4359235
# btw 10 and 100       DONALD TRUMP          2488226
#                      HILLARY CLINTON      68855884
# btw 100 and 1000     DONALD TRUMP         39445281
#                      HILLARY CLINTON      88763686
# btw 1000 and 10000   DONALD TRUMP         16376122
#                      HILLARY CLINTON     130521248
# btw 10000 and 100000 DONALD TRUMP           447493
#                      HILLARY CLINTON       1455955
# abv 100000           DONALD TRUMP         18000000
#                      HILLARY CLINTON             0

# %%
Range = Range.unstack(1).fillna(0)
#Range.columns = ["Donald Trump", "Hillary Clinton"]
Range
# Out:
#                      CONTRIBUTION
# CAND_NAME            DONALD TRUMP HILLARY CLINTON
# CONTRIBUTION
# below 10                    14407         4359235
# btw 10 and 100            2488226        68855884
# btw 100 and 1000         39445281        88763686
# btw 1000 and 10000       16376122       130521248
# btw 10000 and 100000       447493         1455955
# abv 100000               18000000               0

# %%
Range.plot.barh(title = "TOTAL CONTRIBUTION SUM BY RANGE")
plt.ticklabel_format(style='plain', axis = "x")

# %% [markdown]
# # Number of Contributions by Range

# %%
bin = pd.cut(df["CONTRIBUTION"], bins = bins, labels = labels)
bin
# Out:
# 0            btw 10 and 100
# 1            btw 10 and 100
# 2                  below 10
# 3            btw 10 and 100
# 4            btw 10 and 100
#                  ...
# 2662036    btw 100 and 1000
# 2662037    btw 100 and 1000
# 2662038    btw 100 and 1000
# 2662039    btw 100 and 1000
# 2662040    btw 100 and 1000
# Name: CONTRIBUTION, Length: 2662041, dtype: category
# Categories (6, object): ['below 10' < 'btw 10 and 100' < 'btw 100 and 1000' < 'btw 1000 and 10000' < 'btw 10000 and 100000' < 'abv 100000']

# %%
size = df.groupby([bin, "CAND_NAME"]).size()

# %%
size
# Out:
# CONTRIBUTION          CAND_NAME
# below 10              DONALD TRUMP          1517
#                       HILLARY CLINTON     606924
# btw 10 and 100        DONALD TRUMP         34421
#                       HILLARY CLINTON    1557935
# btw 100 and 1000      DONALD TRUMP        104361
#                       HILLARY CLINTON     255669
# btw 1000 and 10000    DONALD TRUMP          6648
#                       HILLARY CLINTON      52432
# btw 10000 and 100000  DONALD TRUMP            21
#                       HILLARY CLINTON         52
# abv 100000            DONALD TRUMP             5
#                       HILLARY CLINTON          0
# dtype: int64

# %%
by_size = pd.DataFrame(size)

# %%
by_size
# Out:
#                                             0
# CONTRIBUTION         CAND_NAME
# below 10             DONALD TRUMP        1517
#                      HILLARY CLINTON   606924
# btw 10 and 100       DONALD TRUMP       34421
#                      HILLARY CLINTON  1557935
# btw 100 and 1000     DONALD TRUMP      104361
#                      HILLARY CLINTON   255669
# btw 1000 and 10000   DONALD TRUMP        6648
#                      HILLARY CLINTON    52432
# btw 10000 and 100000 DONALD TRUMP          21
#                      HILLARY CLINTON       52
# abv 100000           DONALD TRUMP           5
#                      HILLARY CLINTON        0

# %%
by_size = by_size.rename(columns = {0: "NUMBER OF CONTRIBUTORS"}).unstack(1)

# %%
by_size.columns = ["Donal Trump", "hillary Clinton"]

# %%
by_size.plot.bar()
plt.title("Total Numbers of contributors by Range", size = 15)
plt.ticklabel_format(style='plain', axis = "y")

# %% [markdown]
# # Proportion of Range Price by Candidates

# %%
by_size_prop = by_size.div(by_size.sum(1), axis = 0)

# %%
by_size_prop
# Out:
#                       Donal Trump  hillary Clinton
# CONTRIBUTION
# below 10                     0.00             1.00
# btw 10 and 100               0.02             0.98
# btw 100 and 1000             0.29             0.71
# btw 1000 and 10000           0.11             0.89
# btw 10000 and 100000         0.29             0.71
# abv 100000                   1.00             0.00

# %%
by_size_prop.plot.barh()
plt.title("Proportion of contribution by range size", size = 18)
# Out:
# Text(0.5, 1.0, 'Proportion of contribution by range size')
